# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("bhavikjikadara/dog-and-cat-classification-dataset")

print("Path to dataset files:", path)

# %%
src_dir = '/home/swhors/.cache/kagglehub/datasets/bhavikjikadara/dog-and-cat-classification-dataset/versions/1'
des_dir = './data/train'
#!echo $src_dir
#!echo $des_dir
#!cp -fR $src_dir $des_dir

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = (224, 224)
INPUT_SHAPE = (224, 224, 1)
BATCH_SIZE = 32
NUM_CLASSES = 8
EPOCHS = 20

train_gen = ImageDataGenerator(
    rescale=1./255,                 # 픽셀 값을 0에서 1 사이로 정규화
    rotation_range=15,              # 이미지를 무작위로 15°  범위 내에서 회전
    width_shift_range=0.1,          # 이미지를 전체 너비의 최대 10% 내에서 수평 이동
    height_shift_range=0.1,         # 이미지를 전체 높이의 최대 10% 내에서 수직 이동
    zoom_range=0.1,                 # 이미지를 무작위로 최대 10% 확대/축소
    horizontal_flip=True            # 이미지를 무작위로 수평 뒤집기를 적용
)
print(train_gen)
train_dir = './data/train/animal/Cat'
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='grayscale'
)
# 4. 클래스 확인(차종 확인)
class_names = list(train_data.class_indices.keys())
class_names
