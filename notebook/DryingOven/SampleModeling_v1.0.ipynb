# %% [markdown]
# ## **_Sample Modeling_** (for Reinforcement Learning)
#
# * 이 페이지는 "Drying Oven"의 가상 센서 데이터를 이용하여 PPO 모델을 교육하고 예측하는 예제를 구현합니다.
# * PPO는 기본적으로 Liear 모델을 지원합니다.

# %%
# ----------------------------------------------------
# Global 변수 선언
# ----------------------------------------------------

csv_file_name = "drying_oven_sensor.csv"

# %% [markdown]
# #### Step 1 가상 센서 데이터 생성
#
# **시나리오**
# * 문 열림이나 외부 간섭으로 인해 내부 온도가 급격히 떨어질 때, 공기의 흐름(풍압)도 함께 불규칙하게 요동치는 상황을 반영했습니다. 보통 문이 열리면 외부 공기 유입으로 인해 압력이 순간적으로 변하고, 시스템은 이를 보정하기 위해 팬 RPM을 급격히 조절하게 됩니다.
# * 풍압 요동(Pressure Fluctuation): drop_start 지점에서 풍압이 ±10.0 범위로 크게 튀게 설정했습니다. 이는 실제 환경에서 문이 열릴 때 발생하는 압력 차를 모사한 것입니다.
# * 팬 RPM 연동: 풍압이 요동치면 시스템이 이를 보정하려고 하므로, RPM 값도 풍압에 따라 급격히 변화하도록 수식을 연결했습니다.
# * 복구 패턴: 온도가 떨어지는 초기에 풍압이 가장 심하게 요동치고, 온도를 다시 올리는 복구 구간에서는 풍압이 서서히 안정화되는 흐름을 가집니다.
# * 이 데이터를 사용하여 학습시킬 때, 온도 오차뿐만 아니라 풍압의 급격한 변화에 대해서도 마이너스 보상(Penalty)을 주면 더 안정적인 제어 로직을 만들 수 있습니다.

# %%
import pandas as pd
import numpy as np
from enum import Enum

# 1. 설정
n_samples = 2000
target_temp = 80.0
target_pressure = 15.0
data = []

# 초기값 설정
curr_temp = 25.0
curr_hum = 60.0
curr_weight = 5000.0

# 구간 설정
warm_up_end = int(n_samples * 0.1)      # 10%: 초기 가열
drop_start = int(n_samples * 0.5)       # 50% 지점: 이상 발생
recovery_end = drop_start + 100         # 100스텝: 복구 구간
stable_end = int(n_samples * 0.9)       # 이후 90%까지 안정 (전체 약 80% 비중)

class HeatState(Enum):
    heating = 1.0
    stable = 2.0
    overheat = 3.0

for i in range(n_samples):
    # 기본 풍압 상태 (평상시 노이즈)
    press_noise = np.random.normal(0, 0.3)
    
    # 2. 구간별 제어 및 환경 변화
    if i < warm_up_end:
        h_state = HeatState.heating.value
        curr_temp = min(target_temp, curr_temp + np.random.uniform(1.5, 2.5))
        air_pressure = target_pressure + press_noise
        
    elif drop_start <= i < drop_start + 15: 
        # [급격한 하락 및 풍압 요동] - 문 열림/외부 간섭 발생
        h_state = HeatState.stable.value
        curr_temp -= np.random.uniform(4.0, 6.0) # 온도 급락
        # 풍압이 위아래로 크게 요동 (외풍 유입 모사)
        air_pressure = target_pressure + np.random.uniform(-10.0, 10.0) 
        
    elif drop_start + 15 <= i < recovery_end:
        # [복구 구간] - 다시 목표치를 향해 제어
        h_state = HeatState.heating.value
        curr_temp = min(target_temp, curr_temp + np.random.uniform(2.0, 3.5))
        # 풍압을 다시 잡기 위해 과하게 작동하는 상황
        air_pressure = target_pressure + np.random.uniform(-2.0, 4.0)
        
    elif i < stable_end:
        # [안정 구간 - 약 80% 비중]
        h_state = HeatState.stable.value
        curr_temp = target_temp + np.random.uniform(-0.5, 0.5)
        air_pressure = target_pressure + press_noise
        
    else:
        # [마지막 변동 구간]
        h_state = HeatState.overheat.value
        curr_temp += np.random.uniform(0.2, 1.0)
        air_pressure = target_pressure + np.random.uniform(-1.0, 1.0)

    # 3. 물리적 상관관계 반영
    # RPM은 풍압을 만들기 위한 제어 결과값 (P ∝ RPM^2 역산)
    curr_rpm = np.sqrt(max(0.1, air_pressure) / 5.0) * 1000 + np.random.normal(0, 15)
    
    # 나머지 센서값
    curr_surf_temp = curr_temp - np.random.uniform(1.0, 3.0)
    curr_hum = max(10.0, 60.0 - (curr_temp - 25.0) * 0.8 + np.random.normal(0, 1))
    curr_weight -= np.random.uniform(0.1, 0.4)

    data.append([
        round(curr_temp, 2), round(curr_hum, 2), round(curr_weight, 2),
        round(curr_surf_temp, 2), round(curr_rpm, 1), round(air_pressure, 3),
        h_state
    ])

# 4. 데이터프레임 생성
df = pd.DataFrame(data, columns=['internal_temp', 'humidity', 'weight', 'surface_temp', 'fan_rpm', 'air_pressure', 'heater_state'])

# 결과 확인 (요동치는 구간 출력)
print("--- 이상 발생 및 복구 구간 데이터 (500~520번) ---")
print(df.iloc[drop_start-2:drop_start+18][['internal_temp', 'air_pressure', 'fan_rpm', 'heater_state']])

df.to_csv(csv_file_name)
# Out:
# --- 이상 발생 및 복구 구간 데이터 (500~520번) ---
#       internal_temp  air_pressure  fan_rpm  heater_state
# 998           79.64        15.002   1728.7           2.0
# 999           80.06        14.526   1732.4           2.0
# 1000          74.25        13.734   1674.5           2.0
# 1001          69.80        12.309   1559.5           2.0
# 1002          65.19        12.956   1618.2           2.0
# 1003          61.10        18.821   1941.6           2.0
# 1004          55.86         6.771   1175.3           2.0
# 1005          51.66        18.978   1979.7           2.0
# 1006          45.99         5.610   1051.7           2.0
# 1007          40.80         9.048   1359.9           2.0
# 1008          36.60         9.826   1413.1           2.0
# 1009          31.69        24.450   2219.4           2.0
# 1010          27.00        11.075   1484.2           2.0
# 1011          22.70         5.849   1081.5           2.0
# 1012          18.06        11.219   1479.9           2.0
# 1013          13.62        15.297   1756.6           2.0
# 1014           8.90        15.351   1729.2           2.0
# 1015          12.35        17.187   1850.4           1.0
# 1016          15.65        15.408   1769.5           1.0
# 1017          18.18        17.336   1873.5           1.0

# %% [markdown]
# #### Step 2 Env 생성

# %% [markdown]
# ##### 2.1 보상 함수 (풍압 중심 제어)
#
# 데이터에 급격한 온도 하락과 풍압 요동 시나리오가 포함되었으므로, 강화학습 에이전트가 이러한 비정상 상황(Abnormal State)을 빠르게 감지하고 복구하도록 유도하는 보상 함수(Reward Function)를 설계했습니다.
#
# 단순히 현재 온도만 보는 것이 아니라, 풍압의 안정성과 제어의 일관성을 모두 고려한 코드입니다.
# 이 코드는 Gymnasium 환경 내에서 앞서 만든 가상 데이터의 물리 법칙(온도 하락, 풍압 요동 등)을 시뮬레이션하며 에이전트를 학습시킵니다.
#
# 보상 함수에서 풍압(air_pressure)의 비중을 대폭 높이고, 에이전트가 풍압을 목표치(15Pa)에 맞추기 위해 팬 RPM을 정밀하게 제어하도록 로직을 수정했습니다.
#
# 이제 온도는 기본적인 제어 대상이 되며, 풍압의 안정성이 보상의 핵심 지표가 됩니다.
#
# **_보상 함수는 에이전트가 다음 세 가지 목표를 동시에 달성하도록 유도합니다._**
# - 온도 유지: 목표 온도(80도)와의 차이 최소화
# - 풍압 안정: 목표 풍압(15Pa)과의 차이 최소화 및 요동 방지
# - 제어 효율: 불필요하게 팬 RPM이나 히터를 과하게 조작하지 않음 (Penalty)
#
# **_파이프라인의 핵심 구성 요소_**
#
# * Gymnasium Env Interface: step() 함수 내에 에이전트의 액션이 실제 온도와 풍압에 어떻게 영향을 주는지 물리 법칙을 정의했습니다.
# * PPO 알고리즘: Stable Baselines3의 PPO는 제어 시스템에서 안정적인 성능을 보여주는 대표적인 강화학습 알고리즘입니다.
# * Quadratic Penalty: 온도 오차를 제곱(temp_err**2)하여 벌점을 부여함으로써, 목표 온도에서 멀어질수록 에이전트가 더 강하게 반응하도록 유도했습니다.
# * Control Smoothing: ctrl_penalty를 통해 히터나 팬을 너무 급격하게 조작하지 않도록 제한하여 실제 기계의 마모를 고려했습니다.
# 이 파이프라인을 실행하면 에이전트가 초기 25도에서 시작하여 80도 온도와 15Pa 풍압을 찾아가고 유지하는 법을 스스로 터득하게 됩니다.
#
# **_보상 로직의 특징_**
# - Quadratic Pressure Penalty: 풍압 오차에 제곱(\^2)과 가중치(5.0)를 적용하여, 에이전트가 풍압을 15Pa에 맞추는 것을 최우선 순위로 학습하게 했습니다.
# - Pressure Delta Reward: 풍압이 목표치로 접근하는 '방향성'에 보상을 주어, 급격한 요동 구간에서도 에이전트가 포기하지 않고 제어력을 유지하도록 돕습니다.
# - Complex Interaction: 풍압이 높아지면 온도가 낮아지는 냉각 효과가 반영되어 있으므로, 에이전트는 온도를 지키면서도 풍압을 최적화하는 미세한 밸런스를 찾게 됩니다.

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from stable_baselines3 import PPO
import matplotlib.pyplot as plt

class DryingOvenEnv(gym.Env):
    def __init__(self):
        super(DryingOvenEnv, self).__init__()
        # 제어: [히터 출력 증감, 팬 RPM 증감]
        self.action_space = spaces.Box(low=-1.0, high=1.0, shape=(2,), dtype=np.float32)
        # 관측: [내부온도, 습도, 무게, 표면온도, 현재RPM, 풍압]
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(6,), dtype=np.float32)
        
        self.target_temp = 80.0
        self.target_press = 15.0 # 보상의 핵심 목표
        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.array([25.0, 60.0, 5000.0, 24.0, 1500.0, 15.0], dtype=np.float32)
        self.prev_press_error = 0.0
        self.steps = 0
        return self.state, {}

    def step(self, action):
        curr_temp, hum, weight, surf_temp, rpm, press = self.state
        h_ctrl, r_ctrl = action
        
        # 1. 물리 시뮬레이션 (RPM이 풍압에 직접 영향)
        new_rpm = np.clip(rpm + (r_ctrl * 200), 500, 3500)
        # 풍압 물리 법칙: P = (RPM/1000)^2 * 5 + 외부 요동(noise)
        new_press = (new_rpm / 1000)**2 * 5.0 + np.random.normal(0, 0.2)
        
        # 온도는 히터와 풍압(냉각효과)의 영향을 받음
        new_temp = curr_temp + (h_ctrl * 4.0) - (new_press * 0.15)
        
        self.state = np.array([new_temp, hum-0.1, weight-0.1, new_temp*0.9, new_rpm, new_press], dtype=np.float32)
        
        # --- 핵심 수정: 풍압 중심의 보상 설계 (Reward Design) ---
        press_error = abs(self.target_press - new_press)
        temp_error = abs(self.target_temp - new_temp)
        
        # 1) 풍압 보상 (매우 강력한 페널티): 목표 풍압에서 멀어질수록 벌점 증가
        r_press = -(press_error ** 2) * 5.0 
        
        # 2) 풍압 안정성 보상: 이전 스텝보다 풍압 오차가 줄어들면 추가 보상
        r_press_delta = (self.prev_press_error - press_error) * 2.0
        
        # 3) 온도 보상: 기본 수준 유지
        r_temp = -(temp_error ** 2) * 0.5
        
        # 최종 보상 합산 (풍압 가중치 극대화)
        reward = r_press + r_press_delta + r_temp
        
        self.prev_press_error = press_error
        self.steps += 1
        
        terminated = bool(new_temp > 130 or new_press > 50)
        truncated = self.steps >= 500
        
        return self.state, reward, terminated, truncated, {}

# %% [markdown]
# #### Step 3 모방 학습(Behavioral Cloning)으로 PPO 초기화하기

# %% [markdown]
# ##### Step 3.1 가상 데이터를 Transitions 데이터로 변환

# %%
import pandas as pd
import torch
from torch.utils.data import DataLoader, TensorDataset

df = pd.read_csv(csv_file_name)
obs = df[['internal_temp', 'humidity', 'weight', 'surface_temp', 'fan_rpm', 'air_pressure']]
acts = df[['heater_state', 'fan_rpm']]
obs = torch.tensor(obs.values, dtype=torch.float32)
acts = torch.tensor(acts.values, dtype=torch.float32)
print(len(obs))
print(len(acts))
dataset = TensorDataset(obs, acts)
loader = DataLoader(dataset, batch_size=64, shuffle=True)
# Out:
# 2000
# 2000

# %% [markdown]
# ##### 3.2 Trasitions 데이터로 모방 학습 하기
#
# * pytorch를 이용
# * 가상 데이터 준비 및 BC 학습 (Pre-training)
# * 가상 데이터에서 (State) -> (Action) 관계를 지도 학습(Supervised Learning)으로 먼저 익힙니다.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from stable_baselines3 import PPO

# BC 모델 정의 (PPO의 Policy 구조와 맞춤)
class BC_Policy(nn.Module):
    def __init__(self):
        super(BC_Policy, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(6, 64), nn.Tanh(),
            nn.Linear(64, 64), nn.Tanh(),
            nn.Linear(64, 2)
        )
    def forward(self, x): return self.net(x)


def train_bc_model(policy, optimizer, criterion, loader):
    # BC 학습 실행
    print("Behavioral Cloning 학습 중...")
    for epoch in range(50):
        for s, a in loader:
            optimizer.zero_grad()
            loss = criterion(policy(s), a)
            loss.backward()
            optimizer.step()
    print(f"BC 완료. 최종 Loss: {loss.item():.4f}")
    return policy


def train_bc_adm_mseloss(loader):
    bc_model = BC_Policy()
    optimizer = optim.Adam(bc_model.parameters(), lr=1e-3)
    criterion = nn.MSELoss()

    return train_bc_model(policy=bc_model, optimizer=optimizer, criterion=criterion, loader=loader)


bc_model = train_bc_adm_mseloss(loader=loader)
# Out:
# Behavioral Cloning 학습 중...
# BC 완료. 최종 Loss: 1326635.5000

# %% [markdown]
# #### 4 PPO 모델 생성
#
# * pytorch를 이용하여 생성 된 policy 이용

# %% [markdown]
# * 파라미터 설명
#
#   * train_Params = {
#     * "steps": 하나의 echo에 대한 분할 횟수, exam : 2048
#     * "epochs": rpeat count, exam : 10
#     * "learning_rate": 3e-4,
#     * "device": "cpu" }
#   * learning_timesteps = 하나의 epoch에 투입되는 총 데이터, exam : 200000

# %%
def train_with_params(train_params, env, bc_policy, learning_timesteps, model_name, is_torch=True):
    """
     모델 설정 (PPO 알고리즘 사용)
     MlpPolicy: 센서 데이터(벡터) 처리에 적합한 다층 퍼셉트론 신경망
    
    ; param train_params : dict
    ; env : DryingOvenEnv
    ; bc_policy : BC_Policy
    ; is_torch: boolean
    ; model_name: str
    """
    ppo_model = PPO("MlpPolicy",
                    env,
                    verbose=1,
                    n_steps=train_Params["steps"],
                    n_epochs=train_Params["epochs"],
                    learning_rate=train_Params["learning_rate"],
                    device=train_Params["device"])

    # BC 모델의 가중치를 PPO의 actor 네트워크로 복사
    # SB3의 policy 구조에 맞춰 매핑 (간략화된 예시)
    if is_torch:
        with torch.no_grad():
            ppo_model.policy.action_net.weight.copy_(bc_policy.net[-1].weight)
            ppo_model.policy.action_net.bias.copy_(bc_policy.net[-1].bias)

    # 5. 강화학습으로 Fine-tuning (전이 학습)
    print("BC 정책을 기반으로 RL Fine-tuning 시작...")
    ppo_model.learn(total_timesteps=learning_timesteps) # 2만 번의 시행착오를 통해 학습

    # 6. 결과 저장
    ppo_model.save(model_name)
    print(f"모델 저장 완료: {model_name}.zip")
    return ppo_model

# %%
# ----------------------------------------
# light train
# ----------------------------------------

env_4_light = DryingOvenEnv() # 앞서 정의한 풍압 중심 Env
train_Params = {
    "steps": 128, # 하나의 echo에 대한 분할 횟수
    "epochs": 1, # rpeat count
    "learning_rate": 3e-4,
    "device": "cpu"
}
print(f'policy = {bc_model}')
learning_timesteps = 2000 # 하나의 epoch에 투입되는 총 데이터 수
train_with_params(train_params=train_Params,
                  env=env_4_light,
                  bc_policy=bc_model,
                  learning_timesteps=learning_timesteps,
                  model_name="drying_oven_v1",
                  is_torch=True)
# Out:
# policy = BC_Policy(
#   (net): Sequential(
#     (0): Linear(in_features=6, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=64, out_features=2, bias=True)
#   )
# )
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# BC 정책을 기반으로 RL Fine-tuning 시작...
# new_temp = 26.91182518005371
# new_temp = 28.227737426757812
# new_temp = 28.967031478881836
# new_temp = 21.027856826782227
# new_temp = 15.765840530395508
# new_temp = 14.308860778808594
# new_temp = 5.821755886077881
# new_temp = -1.1166644096374512
# new_temp = -5.617786884307861
# new_temp = -8.802816390991211
# new_temp = -12.533502578735352
# new_temp = -18.969161987304688
# new_temp = -20.29058837890625
# new_temp = -24.491527557373047
# new_temp = -27.40738296508789
# new_temp = -29.179214477539062
# new_temp = -31.131193161010742
# new_temp = -37.73530960083008
# new_temp = -47.229854583740234
# new_temp = -54.09196853637695
# new_temp = -59.63336181640625
# new_temp = -66.53834533691406
# new_temp = -68.33429718017578
# new_temp = -68.67887115478516
# new_temp = -75.15779876708984
# new_temp = -81.78872680664062
# new_temp = -87.94783020019531
# new_temp = -89.782470703125
# new_temp = -90.96043395996094
# new_temp = -235.66847229003906
# new_temp = -233.50088500976562
# new_temp = -237.3428192138672
# new_temp = -234.05763244628906
# new_temp = -231.12112426757812
# new_temp = -228.13514709472656
# new_temp = -225.20672607421875
# new_temp = -229.94557189941406
# new_temp = -227.0496063232422
# new_temp = -223.80906677246094
# new_temp = -224.0165557861328
# new_temp = -222.9009246826172
# new_temp = -221.63690185546875
# new_temp = -227.09568786621094
# new_temp = -224.63079833984375
# new_temp = -224.5712127685547
# new_temp = -228.91261291503906
# new_temp = -233.237060546875
# new_temp = -232.77151489257812
# new_temp = -234.06161499023438
# new_temp = -234.274169921875
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1336       |
# |    iterations           | 2          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 256        |
# | train/                  |            |
# |    approx_kl            | 0.15864271 |
# |    clip_fraction        | 0.0703     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.84      |
# |    explained_variance   | 1.01e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.26e+11   |
# |    n_updates            | 1          |
# |    policy_gradient_loss | 0.000201   |
# |    std                  | 1          |
# |    value_loss           | 2.28e+11   |
# ----------------------------------------
# new_temp = -236.7978973388672
# new_temp = -239.52056884765625
# new_temp = -244.32601928710938
# new_temp = -243.88449096679688
# new_temp = -248.63038635253906
# new_temp = -245.25868225097656
# new_temp = -244.1028289794922
# new_temp = -248.72634887695312
# new_temp = -245.60353088378906
# new_temp = -243.92630004882812
# new_temp = -242.16534423828125
# new_temp = -238.97618103027344
# new_temp = -241.5817413330078
# new_temp = -243.76170349121094
# new_temp = -246.75994873046875
# new_temp = -243.9148712158203
# new_temp = -249.01397705078125
# new_temp = -248.8677978515625
# new_temp = -245.7860565185547
# new_temp = -249.04576110839844
# new_temp = -251.8944091796875
# new_temp = -256.5851135253906
# new_temp = -253.593994140625
# new_temp = -250.26280212402344
# new_temp = -247.90835571289062
# new_temp = -248.33470153808594
# new_temp = -245.01719665527344
# new_temp = -242.091796875
# new_temp = -241.59152221679688
# new_temp = -241.8094024658203
# new_temp = -245.82119750976562
# new_temp = -242.80618286132812
# new_temp = -239.5268096923828
# new_temp = -241.35812377929688
# new_temp = -245.60198974609375
# new_temp = -250.64422607421875
# new_temp = -247.29466247558594
# new_temp = -244.32032775878906
# new_temp = -241.02413940429688
# new_temp = -243.8187713623047
# new_temp = -246.6606903076172
# new_temp = -244.18576049804688
# new_temp = -247.3907928466797
# new_temp = -244.92376708984375
# new_temp = -247.07765197753906
# new_temp = -246.6707305908203
# new_temp = -246.61895751953125
# new_temp = -246.0316925048828
# new_temp = -248.54254150390625
# new_temp = -247.28607177734375
# new_temp = -250.59152221679688
# new_temp = -249.82818603515625
# new_temp = -247.2573699951172
# new_temp = -244.26431274414062
# new_temp = -248.9987030029297
# new_temp = -245.9642791748047
# new_temp = -250.64871215820312
# new_temp = -249.705078125
# new_temp = -248.43084716796875
# new_temp = -247.07427978515625
# new_temp = -244.96226501464844
# new_temp = -248.5166778564453
# new_temp = -245.21653747558594
# new_temp = -248.0225067138672
# new_temp = -252.28225708007812
# new_temp = -257.04315185546875
# new_temp = -253.70054626464844
# new_temp = -258.7590637207031
# new_temp = -257.7677001953125
# new_temp = -258.8103942871094
# new_temp = -263.59423828125
# new_temp = -268.0209655761719
# new_temp = -264.8263244628906
# new_temp = -269.2623291015625
# new_temp = -274.08282470703125
# new_temp = -278.6439514160156
# new_temp = -276.09185791015625
# new_temp = -280.4565124511719
# new_temp = -277.2771301269531
# new_temp = -278.0926513671875
# new_temp = -277.0896301269531
# new_temp = -275.9393005371094
# new_temp = -275.9181213378906
# new_temp = -278.6300048828125
# new_temp = -279.0580139160156
# new_temp = -275.6156005859375
# new_temp = -272.42059326171875
# new_temp = -276.5933837890625
# new_temp = -273.3645935058594
# new_temp = -277.858642578125
# new_temp = -274.6928405761719
# new_temp = -275.6121520996094
# new_temp = -280.3819580078125
# new_temp = -280.0305480957031
# new_temp = -276.9528503417969
# new_temp = -273.6118469238281
# new_temp = -273.1167297363281
# new_temp = -273.6611328125
# new_temp = -275.54705810546875
# new_temp = -280.192626953125
# new_temp = -277.1168212890625
# new_temp = -277.6419982910156
# new_temp = -276.0919189453125
# new_temp = -272.9144287109375
# new_temp = -277.8477783203125
# new_temp = -274.5503845214844
# new_temp = -279.6454772949219
# new_temp = -276.33721923828125
# new_temp = -276.2212219238281
# new_temp = -280.9095764160156
# new_temp = -282.4832763671875
# new_temp = -283.5159912109375
# new_temp = -282.0956115722656
# new_temp = -282.67547607421875
# new_temp = -279.7173156738281
# new_temp = -282.64019775390625
# new_temp = -283.5572204589844
# new_temp = -280.27569580078125
# new_temp = -279.0921936035156
# new_temp = -277.9728088378906
# new_temp = -280.6690368652344
# new_temp = -283.5408630371094
# new_temp = -288.30438232421875
# new_temp = -284.8675842285156
# new_temp = -281.7558288574219
# new_temp = -280.6834411621094
# new_temp = -285.1479187011719
# new_temp = -289.6208190917969
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1191       |
# |    iterations           | 3          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 384        |
# | train/                  |            |
# |    approx_kl            | 0.01846778 |
# |    clip_fraction        | 0.0781     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.84      |
# |    explained_variance   | -5.96e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.35e+11   |
# |    n_updates            | 2          |
# |    policy_gradient_loss | 0.0194     |
# |    std                  | 1          |
# |    value_loss           | 4.69e+11   |
# ----------------------------------------
# new_temp = -286.67095947265625
# new_temp = -291.2991638183594
# new_temp = -291.8846740722656
# new_temp = -288.4737854003906
# new_temp = -285.32720947265625
# new_temp = -282.0428771972656
# new_temp = -279.021728515625
# new_temp = -275.68768310546875
# new_temp = -280.70440673828125
# new_temp = -285.2995300292969
# new_temp = -284.71221923828125
# new_temp = -281.7410583496094
# new_temp = -283.0474548339844
# new_temp = -287.6945495605469
# new_temp = -284.6426696777344
# new_temp = -287.36651611328125
# new_temp = -285.7421569824219
# new_temp = -284.22344970703125
# new_temp = -281.2126770019531
# new_temp = -283.8262634277344
# new_temp = -284.1033630371094
# new_temp = -288.8305969238281
# new_temp = -293.5290222167969
# new_temp = -291.0063171386719
# new_temp = -288.0289001464844
# new_temp = -290.9651184082031
# new_temp = -287.977783203125
# new_temp = -284.83892822265625
# new_temp = -288.56256103515625
# new_temp = -292.0792236328125
# new_temp = -289.4286193847656
# new_temp = -294.11260986328125
# new_temp = -291.79254150390625
# new_temp = -289.1215515136719
# new_temp = -294.1142272949219
# new_temp = -298.80853271484375
# new_temp = -295.8225402832031
# new_temp = -299.3837585449219
# new_temp = -296.4498596191406
# new_temp = -296.5325927734375
# new_temp = -301.5274658203125
# new_temp = -302.32666015625
# new_temp = -299.039306640625
# new_temp = -300.3196105957031
# new_temp = -299.6153869628906
# new_temp = -300.5127258300781
# new_temp = -300.306640625
# new_temp = -296.83489990234375
# new_temp = -298.93060302734375
# new_temp = -297.1092834472656
# new_temp = -294.0016174316406
# new_temp = -298.2074279785156
# new_temp = -297.5564270019531
# new_temp = -297.2711486816406
# new_temp = -302.1660461425781
# new_temp = -306.7144470214844
# new_temp = -303.587646484375
# new_temp = -305.9308776855469
# new_temp = -302.9544372558594
# new_temp = -305.2861633300781
# new_temp = -307.6102294921875
# new_temp = -310.6457824707031
# new_temp = -310.73016357421875
# new_temp = -315.3760986328125
# new_temp = -312.3805236816406
# new_temp = -314.35418701171875
# new_temp = -312.3418884277344
# new_temp = -316.7652587890625
# new_temp = -318.009521484375
# new_temp = -317.5920715332031
# new_temp = -315.6015319824219
# new_temp = -312.3196105957031
# new_temp = -309.4186096191406
# new_temp = -306.3283386230469
# new_temp = -308.786376953125
# new_temp = -313.5856018066406
# new_temp = -318.7013244628906
# new_temp = -315.459228515625
# new_temp = -319.18572998046875
# new_temp = -323.9793701171875
# new_temp = -321.0940856933594
# new_temp = -319.68896484375
# new_temp = -319.15234375
# new_temp = -317.2038269042969
# new_temp = -318.7286071777344
# new_temp = -319.2486267089844
# new_temp = -316.13580322265625
# new_temp = -315.4945068359375
# new_temp = -316.8851318359375
# new_temp = -317.63385009765625
# new_temp = -314.3306884765625
# new_temp = -315.0732421875
# new_temp = -311.761962890625
# new_temp = -311.170166015625
# new_temp = -308.6924133300781
# new_temp = -308.7813720703125
# new_temp = -309.92755126953125
# new_temp = -309.7618103027344
# new_temp = -306.4704284667969
# new_temp = -303.4884033203125
# new_temp = -304.2793273925781
# new_temp = -305.8726806640625
# new_temp = -310.5843505859375
# new_temp = -311.59283447265625
# new_temp = -312.55010986328125
# new_temp = -315.064208984375
# new_temp = -316.1068115234375
# new_temp = -319.9044189453125
# new_temp = -316.57012939453125
# new_temp = -313.729736328125
# new_temp = -318.4544372558594
# new_temp = -316.6716003417969
# new_temp = -313.4086608886719
# new_temp = -310.5270690917969
# new_temp = -313.675048828125
# new_temp = -316.3156433105469
# new_temp = 18.845796585083008
# new_temp = 12.166037559509277
# new_temp = 12.860541343688965
# new_temp = 9.118916511535645
# new_temp = 4.12167501449585
# new_temp = -5.17124605178833
# new_temp = -11.994302749633789
# new_temp = -18.38164520263672
# new_temp = -28.287946701049805
# new_temp = -34.10933303833008
# new_temp = -44.249916076660156
# new_temp = -48.59099197387695
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -2.54e+07   |
# | time/                   |             |
# |    fps                  | 1120        |
# |    iterations           | 4           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.035877068 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3
# new_temp = -258.1466979980469
# new_temp = -255.03587341308594
# new_temp = -251.67105102539062
# new_temp = -248.58609008789062
# new_temp = -245.8223419189453
# new_temp = -250.75244140625
# new_temp = -250.98828125
# new_temp = -247.9271697998047
# new_temp = -246.03018188476562
# new_temp = -245.70826721191406
# new_temp = -246.47889709472656
# new_temp = -244.31346130371094
# new_temp = -241.49082946777344
# new_temp = -246.3557891845703
# new_temp = -249.841064453125
# new_temp = -247.3238983154297
# new_temp = -244.47210693359375
# new_temp = -244.6517791748047
# new_temp = -246.42286682128906
# new_temp = -243.63706970214844
# new_temp = -240.48861694335938
# new_temp = -237.6277618408203
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -2.54e+07   |
# | time/                   |             |
# |    fps                  | 1091        |
# |    iterations           | 5           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 640         |
# | train/                  |             |
# |    approx_kl            | 8.76016e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 8.34e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.11e+11    |
# |    n_updates            | 4           |
# |    policy_gradient_loss | 0.000634    |
# |    std                  | 1           |
# |    value_loss           | 1.13e+12    |
# -----------------------------------------
# new_temp = -234.564697265625
# new_temp = -236.0906219482422
# new_temp = -241.02371215820312
# new_temp = -240.79525756835938
# new_temp = -242.12850952148438
# new_temp = -244.14918518066406
# new_temp = -240.8611602783203
# new_temp = -241.885498046875
# new_temp = -243.30519104003906
# new_temp = -243.74609375
# new_temp = -246.08932495117188
# new_temp = -243.0672607421875
# new_temp = -246.0121307373047
# new_temp = -246.68215942382812
# new_temp = -248.6405487060547
# new_temp = -245.69219970703125
# new_temp = -249.23843383789062
# new_temp = -251.42042541503906
# new_temp = -248.101806640625
# new_temp = -245.130859375
# new_temp = -248.93975830078125
# new_temp = -247.70713806152344
# new_temp = -245.4369659423828
# new_temp = -244.72523498535156
# new_temp = -241.35897827148438
# new_temp = -238.32427978515625
# new_temp = -243.21401977539062
# new_temp = -244.70777893066406
# new_temp = -244.5103302001953
# new_temp = -242.7069549560547
# new_temp = -240.8991241455078
# new_temp = -245.1827850341797
# new_temp = -248.28204345703125
# new_temp = -244.87538146972656
# new_temp = -241.7577362060547
# new_temp = -239.00210571289062
# new_temp = -236.34536743164062
# new_temp = -233.59780883789062
# new_temp = -236.9069366455078
# new_temp = -234.12351989746094
# new_temp = -232.25747680664062
# new_temp = -229.50637817382812
# new_temp = -234.42259216308594
# new_temp = -237.7731170654297
# new_temp = -236.82705688476562
# new_temp = -234.11537170410156
# new_temp = -238.9871826171875
# new_temp = -236.2410125732422
# new_temp = -234.20761108398438
# new_temp = -232.23049926757812
# new_temp = -235.7586669921875
# new_temp = -232.9690704345703
# new_temp = -229.86697387695312
# new_temp = -230.17283630371094
# new_temp = -234.08702087402344
# new_temp = -231.3621826171875
# new_temp = -233.2518310546875
# new_temp = -235.97279357910156
# new_temp = -234.42242431640625
# new_temp = -231.6979522705078
# new_temp = -228.62551879882812
# new_temp = -227.06207275390625
# new_temp = -224.00038146972656
# new_temp = -223.22021484375
# new_temp = -220.90298461914062
# new_temp = -218.19219970703125
# new_temp = -223.10362243652344
# new_temp = -221.99612426757812
# new_temp = -226.90365600585938
# new_temp = -224.6580810546875
# new_temp = -224.59170532226562

# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.93e+11   |
# |    n_updates            | 6          |
# |    policy_gradient_loss | -0.00138   |
# |    std                  | 1          |
# |    value_loss           | 5.63e+11   |
# ----------------------------------------
# new_temp = -219.83087158203125
# new_temp = -219.4005889892578
# new_temp = -221.05252075195312
# new_temp = -222.86102294921875
# new_temp = -219.850830078125
# new_temp = -218.66200256347656
# new_temp = -217.78204345703125
# new_temp = -214.427978515625
# new_temp = -213.5292205810547
# new_temp = -210.76373291015625
# new_temp = -213.8163604736328
# new_temp = -216.00599670410156
# new_temp = -213.96444702148438
# new_temp = -210.64122009277344
# new_temp = -207.5395050048828
# new_temp = -205.22137451171875
# new_temp = -202.23707580566406
# new_temp = -198.947021484375
# new_temp = -201.31582641601562
# new_temp = -198.05166625976562
# new_temp = -202.07278442382812
# new_temp = -198.77215576171875
# new_temp = -195.73472595214844
# new_temp = -195.28732299804688
# new_temp = -197.36376953125
# new_temp = -198.2640838623047
# new_temp = -195.17332458496094
# new_temp = -195.55987548828125
# new_temp = -192.4167938232422
# new_temp = -191.6216583251953
# new_temp = -188.5673370361328
# new_temp = -185.8663787841797
# new_temp = -183.10755920410156
# new_temp = -180.33358764648438
# new_temp = -181.26332092285156
# new_temp = -179.90380859375
# new_temp = -179.0452117919922
# new_temp = -181.7727508544922
# new_temp = -184.28631591796875
# new_temp = -185.3794403076172
# new_temp = -188.83279418945312
# new_temp = -189.15280151367188
# new_temp = -188.38706970214844
# new_temp = -185.59837341308594
# new_temp = -182.345703125
# new_temp = -179.53402709960938
# new_temp = -179.7743682861328
# new_temp = -182.17831420898438
# new_temp = -179.29241943359375
# new_temp = -181.6009063720703
# new_temp = -184.888427734375
# new_temp = -186.93980407714844
# new_temp = -190.75262451171875
# new_temp = -187.6953125
# new_temp = -187.9050750732422
# new_temp = -192.5749053955078
# new_temp = -189.8920135498047
# new_temp = -194.8088836669922
# new_temp = -196.51681518554688
# new_temp = -193.42428588867188
# new_temp = -190.73411560058594
# new_temp = -193.94497680664062
# new_temp = -194.26231384277344
# new_temp = -196.4473876953125
# new_temp = -194.9059600830078
# new_temp = -199.8878631591797
# new_temp = -204.50904846191406
# new_temp = -209.3811798095703
# new_temp = -213.86618041992188
# new_temp = -210.84918212890625
# new_temp = -207.8197021484375
# new_temp = -212.71768188476562
# new_temp = -212.06729125976562
# new_temp = -210.01834106445312
# new_temp = -206.64793395996094
# new_temp = -208.53416442871094
# new_temp = -213.149658203125
# new_temp = -213.0819091796875
# new_temp = -211.40472412109375
# new_temp = -208.48638916015625
# new_temp = -205.18209838867188
# new_temp = -202.4052276611328
# new_temp = -200.03086853027344
# new_temp = -198.81150817871094
# new_temp = -195.57720947265625
# new_temp = -192.75022888183594
# new_temp = -189.5088348388672
# new_temp = -187.494873046875
# new_temp = -184.1950225830078
# new_temp = -181.23768615722656
# new_temp = -186.67813110351562
# new_temp = -184.1440887451172
# new_temp = -182.4709930419922
# new_temp = -184.71466064453125
# new_temp = -185.03054809570312
# new_temp = -182.47177124023438
# new_temp = -179.47914123535156
# new_temp = -178.6396942138672
# new_temp = -179.0403289794922
# new_temp = -176.5380401611328
# new_temp = -177.0736541748047
# new_temp = -179.4491424560547
# new_temp = -181.66085815429688
# new_temp = -181.54025268554688
# new_temp = 18.827190399169922
# new_temp = 13.518696784973145
# new_temp = 8.98061466217041
# new_temp = 6.58631706237793
# new_temp = 0.9214067459106445
# new_temp = -3.8775100708007812
# new_temp = -6.023611545562744
# new_temp = -12.491378784179688
# new_temp = -22.616130828857422
# new_temp = -25.21108627319336
# new_temp = -31.703250885009766
# new_temp = -35.58363342285156
# new_temp = -44.550350189208984
# new_temp = -47.3704948425293
# new_temp = -52.180267333984375
# new_temp = -54.53569793701172
# new_temp = -60.50328826904297
# new_temp = -61.647254943847656
# new_temp = -68.2717514038086
# new_temp = -77.42586517333984
# new_temp = -80.96916198730469
# new_temp = -84.87706756591797
# new_temp = -85.30586242675781
# new_temp = -87.7755355834961
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -2.34e+07   |
# | time/                   |             |
# |    fps                  | 980         |
# |    iterations           | 8           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.012811165 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.35e+11    |
# |    n_updates            | 7           |
# |    policy_gradient_loss | -0.00832    |
# |    std                  | 1           |
# |    value_loss           | 4.63e+11    |
# -----------------------------------------
# new_temp = -89.52582550048828
# new_temp = -89.72823333740234
# new_temp = -97.03398132324219
# new_temp = -99.72146606445312
# new_temp = -106.77418518066406
# new_temp = -106.71590423583984
# new_temp = -109.94427490234375
# new_temp = -117.17196655273438
# new_temp = -116.232666015625
# new_temp = -115.94733428955078
# new_temp = -123.05206298828125
# new_temp = -128.5876922607422
# new_temp = -130.30166625976562
# new_temp = -129.5542755126953
# new_temp = -129.5138397216797
# new_temp = -130.37442016601562
# new_temp = -137.4629669189453
# new_temp = -143.96734619140625
# new_temp = -148.50347900390625
# new_temp = -151.62762451171875
# new_temp = -150.69728088378906
# new_temp = -149.1985321044922
# new_temp = -149.62759399414062
# new_temp = -156.1297607421875
# new_temp = -160.62474060058594
# new_temp = -159.23873901367188
# new_temp = -158.477294921875
# new_temp = -156.960693359375
# new_temp = -158.2630615234375
# new_temp = -159.74729919433594
# new_temp = -161.0006561279297
# new_temp = -161.59661865234375
# new_temp = -164.5885772705078
# new_temp = -163.94618225097656
# new_temp = -163.35157775878906
# new_temp = -165.9786834716797
# new_temp = -167.36712646484375
# new_temp = -169.6999053955078
# new_temp = -174.69119262695312
# new_temp = -173.17703247070312
# new_temp = -174.41925048828125
# new_temp = -176.40426635742188
# new_temp = -176.06881713867188
# new_temp = -176.41036987304688
# new_temp = -181.29010009765625
# new_temp = -182.2403564453125
# new_temp = -180.19508361816406
# new_temp = -177.72091674804688
# new_temp = -175.65711975097656
# new_temp = -174.12286376953125
# new_temp = -180.12522888183594
# new_temp = -185.1776580810547
# new_temp = -190.7848663330078
# new_temp = -188.91058349609375
# new_temp = -193.9215545654297
# new_temp = -199.8241424560547
# new_temp = -198.46246337890625
# new_temp = -196.5641326904297
# new_temp = -195.5439910888672
# new_temp = -194.62442016601562
# new_temp = -194.6261444091797
# new_temp = -198.64271545410156
# new_temp = -202.4840850830078
# new_temp = -207.80245971679688
# new_temp = -213.4724884033203
# new_temp = -218.74417114257812
# new_temp = -216.434814453125
# new_temp = -221.5682830810547
|
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95e+11    |
# |    n_updates            | 9           |
# |    policy_gradient_loss | 0.045       |
# |    std                  | 1           |
# |    value_loss           | 3.94e+11    |
# -----------------------------------------
# new_temp = -225.4930419921875
# new_temp = -222.4170379638672
# new_temp = -227.1145782470703
# new_temp = -228.4929656982422
# new_temp = -225.2630157470703
# new_temp = -227.5640106201172
# new_temp = -228.17034912109375
# new_temp = -230.28883361816406
# new_temp = -229.95895385742188
# new_temp = -233.3961639404297
# new_temp = -236.06634521484375
# new_temp = -239.4635467529297
# new_temp = -243.11355590820312
# new_temp = -246.2873077392578
# new_temp = -243.03460693359375
# ...
# new_temp = -256.35650634765625
# new_temp = -255.70838928222656
# new_temp = -252.49014282226562
# new_temp = -251.31390380859375
# new_temp = -248.09291076660156
# new_temp = -245.2003173828125
# new_temp = -244.0166473388672
# new_temp = -243.852294921875
# new_temp = -240.66879272460938
# new_temp = -237.8564910888672
# new_temp = -242.7219696044922
# new_temp = -239.26126098632812
# new_temp = -236.16311645507812
# new_temp = -238.4476318359375
# new_temp = -236.63121032714844
# new_temp = -237.13966369628906
# new_temp = -237.1926727294922
# new_temp = -239.57261657714844
# new_temp = -243.03378295898438
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -2.25e+07   |
# | time/                   |             |
# |    fps                  | 934         |
# |    iterations           | 13          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1664        |
# | train/                  |             |
# |    approx_kl            | 0.024147097 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 1.91e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.38e+11    |
# |    n_updates            | 12          |
# |    policy_gradient_loss | 0.0105      |
# |    std                  | 1           |
# |    value_loss           | 2.79e+11    |
# -----------------------------------------
# new_temp = -239.540771484375
# new_temp = -242.8332061767578
# new_temp = -243.00543212890625
# new_temp = -241.3078155517578
# new_temp = -246.34799194335938
# new_temp = -244.55870056152344
# new_temp = -241.5420684814453
# new_temp = -238.20533752441406
# new_temp = -242.53041076660156
# new_temp = -242.5074005126953
# new_temp = -239.53469848632812
# new_temp = -240.77503967285156
# new_temp = -237.9245147705078
# new_temp = -234.67724609375
# new_temp = -231.7280731201172
# new_temp = -232.875732421875
# new_temp = -229.9099884033203
# new_temp = -234.68382263183594
# new_temp = -235.86346435546875
# new_temp = -234.7959747314453
# new_temp = -239.86328125
# new_temp = -240.16326904296875
# new_temp = -237.216064453125
# new_temp = -240.37965393066406
# new_temp = -237.4414825439453
# new_temp = -235.45217895507812
# new_temp = -236.2417449951172
# new_temp = -233.361572265625
# new_temp = -230.4429473876953
# new_temp = -231.77755737304688
# new_temp = -236.5907440185547
# new_temp = -239.5393524169922
# new_temp = -242.13999938964844
# new_temp = -243.72067260742188
# new_temp = -245.10720825195312
# new_temp = -247.9376983642578
# new_temp = -244.57083129882812
# new_temp = -241.45680236816406
# new_temp = -244.8071746826172
# new_temp = -246.13943481445312
# new_temp = -243.99107360839844
# new_temp = -247.22239685058594
# new_temp = -244.30453491210938
# new_temp = -245.24368286132812
# new_temp = -241.701416015625
# new_temp = -238.3870849609375
# new_temp = -241.05458068847656
# new_temp = -241.386474609375
# new_temp = -246.39903259277344
# new_temp = -247.6865692138672
# new_temp = -251.89920043945312
# new_temp = -251.49166870117188
# new_temp = -248.82763671875
# new_temp = -249.90167236328125
# new_temp = -249.24099731445312
# new_temp = -246.0
# new_temp = -242.44296264648438
# new_temp = -240.45494079589844
# new_temp = -244.23831176757812
# new_temp = -248.76414489746094
# new_temp = -245.26979064941406
# new_temp = -244.10821533203125
# new_temp = -245.74473571777344
# new_temp = -242.45924377441406
# new_temp = -246.29568481445312
# new_temp = -245.33389282226562
# new_temp = -244.1339569091797
# new_temp = -245.15406799316406
# new_temp = -245.5392608642578
# new_temp = -242.1607666015625
# new_temp = -239.12472534179688
# new_temp = -241.30419921875
# new_temp = -238.17242431640625
# new_temp = -242.93045043945312
# new_temp = -243.7089080810547
# new_temp = -240.50254821777344
# new_temp = -239.30081176757812
# new_temp = -236.02513122558594
# new_temp = -234.66441345214844
# new_temp = -231.46888732910156
# new_temp = -230.57485961914062
# new_temp = -228.65798950195312
# new_temp = -225.82460021972656
# new_temp = -228.4835662841797
# new_temp = -226.3304901123047
# new_temp = -223.07093811035156
# new_temp = -220.13636779785156
# new_temp = -223.11489868164062
# new_temp = -227.16616821289062
# new_temp = -225.73904418945312
# new_temp = -230.83224487304688
# new_temp = -227.67514038085938
# new_temp = -228.91102600097656
# new_temp = -230.66403198242188
# new_temp = -231.6258087158203
# new_temp = -234.44171142578125
# new_temp = -235.64511108398438
# new_temp = -232.36663818359375
# new_temp = -232.5331573486328
# new_temp = -237.2971649169922
# new_temp = -239.2796173095703
# new_temp = -236.80828857421875
# new_temp = -233.6886444091797
# new_temp = -230.21701049804688
# new_temp = -227.07925415039062
# new_temp = -231.8542938232422
# new_temp = -228.66409301757812
# new_temp = -231.8660888671875
# new_temp = -236.43576049804688
# new_temp = -238.20753479003906
# new_temp = -235.44808959960938
# new_temp = -232.30540466308594
# new_temp = -233.18502807617188
# new_temp = -230.6468505859375
# new_temp = -235.20143127441406
# new_temp = -238.8915557861328
# new_temp = -243.4652099609375
# new_temp = -242.87606811523438
# new_temp = -244.66552734375
# new_temp = -245.0323944091797
# new_temp = -245.56027221679688
# new_temp = -250.07872009277344
# new_temp = -246.9100341796875
# new_temp = -245.98211669921875
# new_temp = -242.7904815673828
# new_temp = -239.288818359375
# new_temp = -241.12106323242188
# new_temp = -238.7801513671875
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | -2.25e+07  |
# | time/                   |            |
# |    fps                  | 944        |
# |    iterations           | 14         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 1792       |
# | train/                  |            |
# |    approx_kl            | 0.11524058 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.84      |
# |    explained_variance   | 9.54e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.09e+11   |
# |    n_updates            | 13         |
# |    policy_gradient_loss | 0.0256     |
# |    std                  | 1          |
# |    value_loss           | 4.32e+11   |
# ----------------------------------------
# new_temp = -235.57078552246094
# new_temp = -234.75924682617188
# new_temp = -231.55892944335938
# new_temp = -229.5081024169922
# new_temp = -230.90635681152344
# new_temp = -227.45884704589844
# new_temp = -225.25106811523438
# new_temp = -228.52308654785156
# new_temp = -233.2325439453125
# new_temp = -231.343017578125
# new_temp = -232.21466064453125
# new_temp = -230.4537353515625
# new_temp = -227.16009521484375
# new_temp = -232.22605895996094
# new_temp = -228.97988891601562
# new_temp = -233.45639038085938
# new_temp = -232.94281005859375
# new_temp = -234.81329345703125
# new_temp = -234.0864715576172
# new_temp = -238.66159057617188
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -2.25e+07    |
# | time/                   |              |
# |    fps                  | 947          |
# |    iterations           | 15           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 1920         |
# | train/                  |              |
# |    approx_kl            | 0.0044921003 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.86e+11     |
# |    n_updates            | 14           |
# |    policy_gradient_loss | 0.00163      |
# |    std                  | 1            |
# |    value_loss           | 6.04e+11     |
# ------------------------------------------
# new_temp = -215.29978942871094
# new_temp = -211.95518493652344
# new_temp = -208.89678955078125
# new_temp = -212.5401611328125
# new_temp = -213.79702758789062
# new_temp = -210.644287109375
# new_temp = -209.98245239257812
# new_temp = -209.96730041503906
# new_temp = -208.533447265625
# new_temp = -205.20362854003906
# new_temp = -205.5410614013672
# new_temp = -203.74208068847656
# new_temp = -208.6319580078125
# new_temp = -208.16989135742188
# new_temp = -209.62466430664062
# new_temp = -212.13494873046875
# new_temp = -215.15240478515625
# new_temp = -211.61343383789062
# new_temp = -209.89596557617188
# new_temp = -208.5880889892578
# new_temp = -205.318359375
# new_temp = -202.33554077148438
# new_temp = -199.09349060058594
# new_temp = -203.87933349609375
# new_temp = -208.61428833007812
# new_temp = -210.1955108642578
# new_temp = -214.67665100097656
# new_temp = -211.72726440429688
# new_temp = -208.68690490722656
# new_temp = -205.38583374023438
# new_temp = -205.8529052734375
# new_temp = -204.76771545410156
# new_temp = -201.7976531982422
# new_temp = -198.52523803710938
# new_temp = -200.7839813232422
# new_temp = -203.459228515625
# new_temp = -200.45574951171875
# new_temp = -200.3193359375
# new_temp = -197.5570068359375
# new_temp = -196.17027282714844
# new_temp = -194.6912384033203
# new_temp = -191.390380859375
# new_temp = -196.4072723388672
# new_temp = -196.73460388183594
# new_temp = -193.7513427734375
# new_temp = -198.42771911621094
# new_temp = -195.74993896484375
# new_temp = -200.5166015625
# new_temp = -198.6458282470703
# new_temp = -195.4204559326172
# new_temp = -198.3050079345703
# new_temp = -201.99697875976562
# new_temp = -199.74208068847656
# new_temp = -198.56752014160156
# new_temp = -195.5843505859375
# new_temp = -193.5261688232422
# new_temp = -192.52809143066406
# new_temp = -191.70970153808594
# new_temp = -188.8545684814453
# new_temp = -185.67465209960938
# new_temp = -184.13912963867188
# new_temp = -187.99258422851562
# new_temp = -185.28414916992188
# new_temp = -184.62982177734375
# new_temp = -185.4976348876953
# new_temp = -184.55580139160156
# new_temp = -185.02743530273438
# new_temp = -181.98802185058594
# new_temp = -186.170654296875
# new_temp = -183.06919860839844
# new_temp = -184.73927307128906
# new_temp = -189.62393188476562
# new_temp = -194.9121551513672
# new_temp = -191.8613739013672
# new_temp = -190.85812377929688
# new_temp = -190.8968048095703
# new_temp = -190.8711395263672
# new_temp = -190.1256866455078
# new_temp = -194.8960723876953
# new_temp = -191.97769165039062
# new_temp = 26.827608108520508
# new_temp = 26.086700439453125
# new_temp = 19.956295013427734
# new_temp = 17.188535690307617
# new_temp = 16.491897583007812
# new_temp = 14.375173568725586
# new_temp = 11.714914321899414
# new_temp = 1.4071564674377441
# new_temp = -8.185068130493164
# new_temp = -10.178987503051758
# new_temp = -16.097148895263672
# new_temp = -19.035972595214844
# new_temp = -20.854942321777344
# new_temp = -31.012256622314453
# new_temp = -40.31108474731445
# new_temp = -41.603248596191406
# new_temp = -42.93364334106445
# new_temp = -50.354408264160156
# new_temp = -54.54277801513672
# new_temp = -55.0926513671875
# new_temp = -59.386959075927734
# new_temp = -62.46364212036133
# new_temp = -62.277748107910156
# new_temp = -62.827880859375
# new_temp = -67.91080474853516
# new_temp = -69.58834075927734
# new_temp = -74.79643249511719
# new_temp = -75.35272216796875
# new_temp = -75.15174102783203
# new_temp = -81.35489654541016
# new_temp = -88.05872344970703
# new_temp = -89.81615447998047
# new_temp = -91.97012329101562
# new_temp = -95.97025299072266
# new_temp = -95.80139923095703
# new_temp = -99.80751037597656
# new_temp = -100.78878784179688
# new_temp = -103.60884094238281
# new_temp = -106.7585220336914
# new_temp = -111.38094329833984
# new_temp = -113.58660125732422
# new_temp = -118.64276123046875
# new_temp = -124.62413024902344
# new_temp = -131.1865692138672
# new_temp = -130.9741668701172
# new_temp = -130.32943725585938
# new_temp = -130.77279663085938
# new_temp = -132.59515380859375
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 500        |
# |    ep_rew_mean          | -2.23e+07  |
# | time/                   |            |
# |    fps                  | 944        |
# |    iterations           | 16         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.03617581 |
# |    clip_fraction        | 0.0859     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.84      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.73e+11   |
# |    n_updates            | 15         |
# |    policy_gradient_loss | 0.017      |
# |    std                  | 1          |
# |    value_loss           | 5.49e+11   |
# ----------------------------------------
# 모델 저장 완료: drying_oven_v1.zip

# %%
# ----------------------------------------
# Heavy Train
# ----------------------------------------

env_4_heavy = DryingOvenEnv() # 앞서 정의한 풍압 중심 Env
train_Params = {
    "steps": 2048,
    "epochs": 10,
    "learning_rate": 3e-4,
    "device": "cpu"
}
learning_timesteps = 200000
train_with_params(train_params=train_Params,
                  env=env_4_heavy,
                  bc_policy=bc_model,
                  learning_timesteps=learning_timesteps,
                  model_name="drying_oven_v1",
                  is_torch=True)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# BC 정책을 기반으로 RL Fine-tuning 시작...
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 9.01      |
# |    ep_rew_mean     | -4.46e+04 |
# | time/              |           |
# |    fps             | 4687      |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 2048      |
# ----------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9.02           |
# |    ep_rew_mean          | -4.45e+04      |
# | time/                   |                |
# |    fps                  | 234            |
# |    iterations           | 2              |
# |    time_elapsed         | 17             |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.087495014    |
# |    clip_fraction        | 0.094          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.84          |
# |    explained_variance   | -2.4914742e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.93e+08       |
# |    n_updates            | 10             |
# |    policy_gradient_loss | 0.0172         |
# |    std                  | 1              |
# |    value_loss           | 7.99e+08       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -4.28e+04     |
# | time/                   |               |
# |    fps                  | 172           |
# |    iterations           | 3             |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.005607733   |
# |    clip_fraction        | 0.0546        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 1.3709068e-06 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.65e+08      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00539      |
# |    std                  | 0.999         |
# |    value_loss           | 7.79e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.02         |
# |    ep_rew_mean          | -4.29e+04    |
# | time/                   |              |
# |    fps                  | 153          |
# |    iterations           | 4            |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0045849727 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 5.364418e-07 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.6e+08      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 0.999        |
# |    value_loss           | 7.42e+08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.03          |
# |    ep_rew_mean          | -4.25e+04     |
# | time/                   |               |
# |    fps                  | 143           |
# |    iterations           | 5             |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.0068631517  |
# |    clip_fraction        | 0.055         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 2.9802322e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.48e+08      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.0059       |
# |    std                  | 0.998         |
# |    value_loss           | 7.24e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -4.09e+04     |
# | time/                   |               |
# |    fps                  | 137           |
# |    iterations           | 6             |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.0035120775  |
# |    clip_fraction        | 0.0061        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 2.3841858e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.38e+08      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00341      |
# |    std                  | 0.998         |
# |    value_loss           | 7.2e+08       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -4.03e+04     |
# | time/                   |               |
# |    fps                  | 133           |
# |    iterations           | 7             |
# |    time_elapsed         | 107           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.005762713   |
# |    clip_fraction        | 0.0324        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.7881393e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.13e+08      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.0063       |
# |    std                  | 0.997         |
# |    value_loss           | 6.76e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.01          |
# |    ep_rew_mean          | -4.01e+04     |
# | time/                   |               |
# |    fps                  | 132           |
# |    iterations           | 8             |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.004380781   |
# |    clip_fraction        | 0.0253        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.1920929e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.68e+08      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00551      |
# |    std                  | 0.996         |
# |    value_loss           | 6.6e+08       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9           |
# |    ep_rew_mean          | -3.93e+04   |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 9           |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015771018 |
# |    clip_fraction        | 0.0184      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.0         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.06e+08    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00566    |
# |    std                  | 0.995       |
# |    value_loss           | 6.41e+08    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.01          |
# |    ep_rew_mean          | -3.91e+04     |
# | time/                   |               |
# |    fps                  | 127           |
# |    iterations           | 10            |
# |    time_elapsed         | 160           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.003940684   |
# |    clip_fraction        | 0.0173        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.1920929e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.99e+08      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.00349      |
# |    std                  | 0.994         |
# |    value_loss           | 6.25e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.01         |
# |    ep_rew_mean          | -3.85e+04    |
# | time/                   |              |
# |    fps                  | 126          |
# |    iterations           | 11           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0059366045 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.13e+08     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00616     |
# |    std                  | 0.993        |
# |    value_loss           | 6.1e+08      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.01        |
# |    ep_rew_mean          | -3.82e+04   |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 12          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.001821667 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.0         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.04e+08    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00268    |
# |    std                  | 0.992       |
# |    value_loss           | 5.92e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9           |
# |    ep_rew_mean          | -3.82e+04   |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 13          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005013731 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.0         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.66e+08    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0032     |
# |    std                  | 0.992       |
# |    value_loss           | 5.76e+08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.75e+04    |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 14           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0103213275 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.87e+08     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00458     |
# |    std                  | 0.991        |
# |    value_loss           | 5.84e+08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -3.77e+04     |
# | time/                   |               |
# |    fps                  | 123           |
# |    iterations           | 15            |
# |    time_elapsed         | 249           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.003316604   |
# |    clip_fraction        | 0.0198        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.82         |
# |    explained_variance   | 5.9604645e-08 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.85e+08      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00344      |
# |    std                  | 0.989         |
# |    value_loss           | 5.7e+08       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.04         |
# |    ep_rew_mean          | -3.78e+04    |
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 16           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0053835493 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77e+08     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00448     |
# |    std                  | 0.988        |
# |    value_loss           | 5.7e+08      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.02          |
# |    ep_rew_mean          | -3.72e+04     |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 17            |
# |    time_elapsed         | 283           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.008960903   |
# |    clip_fraction        | 0.0326        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 1.1920929e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.63e+08      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00292      |
# |    std                  | 0.988         |
# |    value_loss           | 5.53e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.03          |
# |    ep_rew_mean          | -3.71e+04     |
# | time/                   |               |
# |    fps                  | 122           |
# |    iterations           | 18            |
# |    time_elapsed         | 301           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00203893    |
# |    clip_fraction        | 0.0124        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | 5.9604645e-08 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.54e+08      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00105      |
# |    std                  | 0.986         |
# |    value_loss           | 5.52e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.68e+04    |
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 19           |
# |    time_elapsed         | 318          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0027409033 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42e+08     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 0.985        |
# |    value_loss           | 5.45e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.63e+04    |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 20           |
# |    time_elapsed         | 336          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0034281062 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.69e+08     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00229     |
# |    std                  | 0.984        |
# |    value_loss           | 5.37e+08     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9.01           |
# |    ep_rew_mean          | -3.64e+04      |
# | time/                   |                |
# |    fps                  | 121            |
# |    iterations           | 21             |
# |    time_elapsed         | 353            |
# |    total_timesteps      | 43008          |
# | train/                  |                |
# |    approx_kl            | 0.0032140398   |
# |    clip_fraction        | 0.0286         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.8           |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.78e+08       |
# |    n_updates            | 200            |
# |    policy_gradient_loss | -0.00148       |
# |    std                  | 0.983          |
# |    value_loss           | 5.27e+08       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.02          |
# |    ep_rew_mean          | -3.66e+04     |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 22            |
# |    time_elapsed         | 370           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.0031930874  |
# |    clip_fraction        | 0.0142        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.8          |
# |    explained_variance   | 5.9604645e-08 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.6e+08       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000318     |
# |    std                  | 0.983         |
# |    value_loss           | 5.26e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.02          |
# |    ep_rew_mean          | -3.65e+04     |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 23            |
# |    time_elapsed         | 387           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.0037405796  |
# |    clip_fraction        | 0.0109        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.8          |
# |    explained_variance   | 1.1920929e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.7e+08       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000181     |
# |    std                  | 0.982         |
# |    value_loss           | 5.26e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.02         |
# |    ep_rew_mean          | -3.65e+04    |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 24           |
# |    time_elapsed         | 404          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0010207439 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.8e+08      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000938    |
# |    std                  | 0.98         |
# |    value_loss           | 5.23e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.01         |
# |    ep_rew_mean          | -3.62e+04    |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 25           |
# |    time_elapsed         | 421          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0007723478 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.74e+08     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000778    |
# |    std                  | 0.98         |
# |    value_loss           | 5.22e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.03         |
# |    ep_rew_mean          | -3.64e+04    |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 26           |
# |    time_elapsed         | 438          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0027288827 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.62e+08     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000154    |
# |    std                  | 0.98         |
# |    value_loss           | 5.22e+08     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9.02           |
# |    ep_rew_mean          | -3.63e+04      |
# | time/                   |                |
# |    fps                  | 121            |
# |    iterations           | 27             |
# |    time_elapsed         | 456            |
# |    total_timesteps      | 55296          |
# | train/                  |                |
# |    approx_kl            | 0.004859873    |
# |    clip_fraction        | 0.0545         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.8           |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.71e+08       |
# |    n_updates            | 260            |
# |    policy_gradient_loss | -0.00429       |
# |    std                  | 0.978          |
# |    value_loss           | 5.28e+08       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.58e+04    |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 28           |
# |    time_elapsed         | 473          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0028825179 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.37e+08     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0018      |
# |    std                  | 0.978        |
# |    value_loss           | 5.16e+08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.01          |
# |    ep_rew_mean          | -3.62e+04     |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 29            |
# |    time_elapsed         | 489           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.0027487925  |
# |    clip_fraction        | 0.0143        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.79         |
# |    explained_variance   | 5.9604645e-08 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.44e+08      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000638     |
# |    std                  | 0.977         |
# |    value_loss           | 5.1e+08       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.03         |
# |    ep_rew_mean          | -3.62e+04    |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 30           |
# |    time_elapsed         | 507          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0038187576 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.65e+08     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00167     |
# |    std                  | 0.976        |
# |    value_loss           | 5.13e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.02         |
# |    ep_rew_mean          | -3.59e+04    |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 31           |
# |    time_elapsed         | 523          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0023296592 |
# |    clip_fraction        | 0.00942      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.32e+08     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000737    |
# |    std                  | 0.976        |
# |    value_loss           | 5.14e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.02         |
# |    ep_rew_mean          | -3.58e+04    |
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 32           |
# |    time_elapsed         | 541          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0030473664 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.57e+08     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000976    |
# |    std                  | 0.975        |
# |    value_loss           | 5.1e+08      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.01        |
# |    ep_rew_mean          | -3.58e+04   |
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 33          |
# |    time_elapsed         | 558         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003429277 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.0         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.39e+08    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00492    |
# |    std                  | 0.974       |
# |    value_loss           | 5.07e+08    |
# -----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9.03           |
# |    ep_rew_mean          | -3.59e+04      |
# | time/                   |                |
# |    fps                  | 121            |
# |    iterations           | 34             |
# |    time_elapsed         | 574            |
# |    total_timesteps      | 69632          |
# | train/                  |                |
# |    approx_kl            | 0.003034987    |
# |    clip_fraction        | 0.0157         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.78          |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.56e+08       |
# |    n_updates            | 330            |
# |    policy_gradient_loss | -0.00192       |
# |    std                  | 0.974          |
# |    value_loss           | 5.06e+08       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.01          |
# |    ep_rew_mean          | -3.57e+04     |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 35            |
# |    time_elapsed         | 590           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.0022942412  |
# |    clip_fraction        | 0.0131        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 5.9604645e-08 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.56e+08      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000955     |
# |    std                  | 0.973         |
# |    value_loss           | 5.07e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -3.56e+04     |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 36            |
# |    time_elapsed         | 608           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.0007644095  |
# |    clip_fraction        | 0.0215        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 1.1920929e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.4e+08       |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 0.000284      |
# |    std                  | 0.972         |
# |    value_loss           | 5e+08         |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9.01           |
# |    ep_rew_mean          | -3.56e+04      |
# | time/                   |                |
# |    fps                  | 121            |
# |    iterations           | 37             |
# |    time_elapsed         | 624            |
# |    total_timesteps      | 75776          |
# | train/                  |                |
# |    approx_kl            | 0.0033210914   |
# |    clip_fraction        | 0.0284         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.78          |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.42e+08       |
# |    n_updates            | 360            |
# |    policy_gradient_loss | -0.000937      |
# |    std                  | 0.972          |
# |    value_loss           | 5.02e+08       |
# --------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.02        |
# |    ep_rew_mean          | -3.58e+04   |
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 38          |
# |    time_elapsed         | 641         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.005547015 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.0         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.72e+08    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00249    |
# |    std                  | 0.971       |
# |    value_loss           | 5.01e+08    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.01       |
# |    ep_rew_mean          | -3.56e+04  |
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 39         |
# |    time_elapsed         | 659        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.00422161 |
# |    clip_fraction        | 0.0296     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.78      |
# |    explained_variance   | 0.0        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.39e+08   |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0011    |
# |    std                  | 0.971      |
# |    value_loss           | 5.01e+08   |
# ----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9.02           |
# |    ep_rew_mean          | -3.57e+04      |
# | time/                   |                |
# |    fps                  | 121            |
# |    iterations           | 40             |
# |    time_elapsed         | 675            |
# |    total_timesteps      | 81920          |
# | train/                  |                |
# |    approx_kl            | 0.002844947    |
# |    clip_fraction        | 0.00698        |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.78          |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.42e+08       |
# |    n_updates            | 390            |
# |    policy_gradient_loss | -0.00156       |
# |    std                  | 0.97           |
# |    value_loss           | 4.97e+08       |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9.02           |
# |    ep_rew_mean          | -3.54e+04      |
# | time/                   |                |
# |    fps                  | 121            |
# |    iterations           | 41             |
# |    time_elapsed         | 691            |
# |    total_timesteps      | 83968          |
# | train/                  |                |
# |    approx_kl            | 0.0035889465   |
# |    clip_fraction        | 0.0339         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.78          |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.51e+08       |
# |    n_updates            | 400            |
# |    policy_gradient_loss | -0.00101       |
# |    std                  | 0.969          |
# |    value_loss           | 4.99e+08       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.01          |
# |    ep_rew_mean          | -3.54e+04     |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 42            |
# |    time_elapsed         | 708           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.0031010373  |
# |    clip_fraction        | 0.0143        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.78         |
# |    explained_variance   | 1.7881393e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.48e+08      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000734     |
# |    std                  | 0.969         |
# |    value_loss           | 4.95e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.03          |
# |    ep_rew_mean          | -3.56e+04     |
# | time/                   |               |
# |    fps                  | 121           |
# |    iterations           | 43            |
# |    time_elapsed         | 725           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.0021362319  |
# |    clip_fraction        | 0.00874       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 1.7881393e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.22e+08      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.00062      |
# |    std                  | 0.968         |
# |    value_loss           | 4.94e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.03         |
# |    ep_rew_mean          | -3.54e+04    |
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 44           |
# |    time_elapsed         | 742          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0035010178 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51e+08     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000855    |
# |    std                  | 0.968        |
# |    value_loss           | 4.95e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.03        |
# |    ep_rew_mean          | -3.54e+04   |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 45          |
# |    time_elapsed         | 762         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.003380226 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.0         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.4e+08     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -7.38e-05   |
# |    std                  | 0.967       |
# |    value_loss           | 4.94e+08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.53e+04    |
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 46           |
# |    time_elapsed         | 785          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0007915983 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46e+08     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00158     |
# |    std                  | 0.967        |
# |    value_loss           | 4.94e+08     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9.01           |
# |    ep_rew_mean          | -3.53e+04      |
# | time/                   |                |
# |    fps                  | 119            |
# |    iterations           | 47             |
# |    time_elapsed         | 803            |
# |    total_timesteps      | 96256          |
# | train/                  |                |
# |    approx_kl            | 0.003265225    |
# |    clip_fraction        | 0.0337         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.77          |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.57e+08       |
# |    n_updates            | 460            |
# |    policy_gradient_loss | -0.00124       |
# |    std                  | 0.966          |
# |    value_loss           | 4.89e+08       |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9              |
# |    ep_rew_mean          | -3.53e+04      |
# | time/                   |                |
# |    fps                  | 119            |
# |    iterations           | 48             |
# |    time_elapsed         | 825            |
# |    total_timesteps      | 98304          |
# | train/                  |                |
# |    approx_kl            | 0.007549214    |
# |    clip_fraction        | 0.0217         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.77          |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.52e+08       |
# |    n_updates            | 470            |
# |    policy_gradient_loss | 0.000946       |
# |    std                  | 0.966          |
# |    value_loss           | 4.87e+08       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -3.51e+04     |
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 49            |
# |    time_elapsed         | 845           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.004825215   |
# |    clip_fraction        | 0.0422        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 1.7881393e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.41e+08      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.00132      |
# |    std                  | 0.965         |
# |    value_loss           | 4.86e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.03          |
# |    ep_rew_mean          | -3.55e+04     |
# | time/                   |               |
# |    fps                  | 118           |
# |    iterations           | 50            |
# |    time_elapsed         | 864           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.0047113523  |
# |    clip_fraction        | 0.0183        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 1.1920929e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.46e+08      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | 7.21e-05      |
# |    std                  | 0.965         |
# |    value_loss           | 4.9e+08       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.51e+04    |
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 51           |
# |    time_elapsed         | 881          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0030348282 |
# |    clip_fraction        | 0.034        |
# ...
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0023567807 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.52e+08     |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.000591    |
# |    std                  | 0.951        |
# |    value_loss           | 4.74e+08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -3.5e+04      |
# | time/                   |               |
# |    fps                  | 112           |
# |    iterations           | 83            |
# |    time_elapsed         | 1516          |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 0.0032798387  |
# |    clip_fraction        | 0.0177        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 1.7881393e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.35e+08      |
# |    n_updates            | 820           |
# |    policy_gradient_loss | -0.00096      |
# |    std                  | 0.951         |
# |    value_loss           | 4.76e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -3.51e+04     |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 84            |
# |    time_elapsed         | 1541          |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 0.0021099471  |
# |    clip_fraction        | 0.0277        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 1.7881393e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.32e+08      |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -0.000439     |
# |    std                  | 0.951         |
# |    value_loss           | 4.73e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -3.51e+04     |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 85            |
# |    time_elapsed         | 1560          |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 0.0025608926  |
# |    clip_fraction        | 0.0302        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 1.7881393e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.5e+08       |
# |    n_updates            | 840           |
# |    policy_gradient_loss | -0.000575     |
# |    std                  | 0.951         |
# |    value_loss           | 4.74e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -3.51e+04     |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 86            |
# |    time_elapsed         | 1579          |
# |    total_timesteps      | 176128        |
# | train/                  |               |
# |    approx_kl            | 0.005056361   |
# |    clip_fraction        | 0.0223        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.74         |
# |    explained_variance   | 1.7881393e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.28e+08      |
# |    n_updates            | 850           |
# |    policy_gradient_loss | -0.00101      |
# |    std                  | 0.95          |
# |    value_loss           | 4.73e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.5e+04     |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 87           |
# |    time_elapsed         | 1596         |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0006541547 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42e+08     |
# |    n_updates            | 860          |
# |    policy_gradient_loss | 0.00095      |
# |    std                  | 0.951        |
# |    value_loss           | 4.73e+08     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9          |
# |    ep_rew_mean          | -3.5e+04   |
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 88         |
# |    time_elapsed         | 1614       |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.00204466 |
# |    clip_fraction        | 0.00918    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.0        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.34e+08   |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.000315  |
# |    std                  | 0.95       |
# |    value_loss           | 4.73e+08   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9           |
# |    ep_rew_mean          | -3.51e+04   |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 89          |
# |    time_elapsed         | 1632        |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.004130491 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.0         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.44e+08    |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00108    |
# |    std                  | 0.95        |
# |    value_loss           | 4.73e+08    |
# -----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9              |
# |    ep_rew_mean          | -3.51e+04      |
# | time/                   |                |
# |    fps                  | 111            |
# |    iterations           | 90             |
# |    time_elapsed         | 1651           |
# |    total_timesteps      | 184320         |
# | train/                  |                |
# |    approx_kl            | 0.000845494    |
# |    clip_fraction        | 0.0217         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.73          |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.4e+08        |
# |    n_updates            | 890            |
# |    policy_gradient_loss | -0.000283      |
# |    std                  | 0.948          |
# |    value_loss           | 4.74e+08       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -3.5e+04      |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 91            |
# |    time_elapsed         | 1671          |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.0014047527  |
# |    clip_fraction        | 0.0117        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | 1.7881393e-07 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.34e+08      |
# |    n_updates            | 900           |
# |    policy_gradient_loss | 0.000555      |
# |    std                  | 0.948         |
# |    value_loss           | 4.73e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.5e+04     |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 92           |
# |    time_elapsed         | 1689         |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0035818478 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.56e+08     |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 0.948        |
# |    value_loss           | 4.73e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.51e+04    |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 93           |
# |    time_elapsed         | 1706         |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0032296642 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39e+08     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.000933    |
# |    std                  | 0.946        |
# |    value_loss           | 4.72e+08     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9              |
# |    ep_rew_mean          | -3.5e+04       |
# | time/                   |                |
# |    fps                  | 111            |
# |    iterations           | 94             |
# |    time_elapsed         | 1724           |
# |    total_timesteps      | 192512         |
# | train/                  |                |
# |    approx_kl            | 0.002848921    |
# |    clip_fraction        | 0.022          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.73          |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.29e+08       |
# |    n_updates            | 930            |
# |    policy_gradient_loss | -0.000217      |
# |    std                  | 0.946          |
# |    value_loss           | 4.72e+08       |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 9              |
# |    ep_rew_mean          | -3.5e+04       |
# | time/                   |                |
# |    fps                  | 111            |
# |    iterations           | 95             |
# |    time_elapsed         | 1741           |
# |    total_timesteps      | 194560         |
# | train/                  |                |
# |    approx_kl            | 0.0025625995   |
# |    clip_fraction        | 0.0132         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.73          |
# |    explained_variance   | -1.1920929e-07 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.4e+08        |
# |    n_updates            | 940            |
# |    policy_gradient_loss | -0.00106       |
# |    std                  | 0.945          |
# |    value_loss           | 4.71e+08       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9             |
# |    ep_rew_mean          | -3.5e+04      |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 96            |
# |    time_elapsed         | 1759          |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.0042724963  |
# |    clip_fraction        | 0.0254        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.73         |
# |    explained_variance   | 5.9604645e-08 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.42e+08      |
# |    n_updates            | 950           |
# |    policy_gradient_loss | -0.000418     |
# |    std                  | 0.946         |
# |    value_loss           | 4.71e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.5e+04     |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 97           |
# |    time_elapsed         | 1776         |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0025863405 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36e+08     |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 0.000481     |
# |    std                  | 0.946        |
# |    value_loss           | 4.71e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9            |
# |    ep_rew_mean          | -3.5e+04     |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 98           |
# |    time_elapsed         | 1793         |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0018382482 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.0          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.41e+08     |
# |    n_updates            | 970          |
# |    policy_gradient_loss | 0.000345     |
# |    std                  | 0.946        |
# |    value_loss           | 4.7e+08      |
# ------------------------------------------
# 모델 저장 완료: oven_control_model.zip

# %% [markdown]
# ##### 5. Test

# %%
# 테스트 실행
model = ppo_model_torch

obs, _ = env.reset()
press_history = []

for _ in range(100):
    action, _ = model.predict(obs)
    obs, r, _, _, _ = env.step(action)
    press_history.append(obs[5]) # air_pressure 기록

plt.plot(press_history, label='Air Pressure (Pa)')
plt.axhline(15, color='r', linestyle='--', label='Target')
plt.title("Reward-Driven Pressure Control")
plt.legend()
plt.show()

# %% [markdown]
# #### 6. 센서 데이터 읽어서 예측 결과를 모터에 전송하기

# %% [markdown]
# ** 센서 데이터 읽기 **
#
# * 실제 환경에 적용하기 위해 외부 센서 데이터(CSV, API, 또는 PLC 통신 등)를 실시간으로 읽어와서 학습된 BC-PPO 모델에 입력하고, 제어 명령(Action)을 출력하는 루프를 추가했습니다.
# * 센서 데이터를 읽어오는 부분은 실제 환경에 맞춰 교체할 수 있도록 read_external_sensors() 함수로 추상화했습니다.
# * 주요 연동 포인트
#   * Observation 정규화: 학습 때 사용한 데이터의 범위와 실제 센서 데이터의 범위가 크게 다를 경우, (obs - mean) / std와 같은 Scaling 과정을 read_external_sensors 내에 추가해야 모델이 정확하게 판단합니다.
#   * Deterministic Prediction: 실전 제어에서는 확률적인 탐색보다는 모델이 가장 좋다고 판단하는 확정적인 값(deterministic=True)을 사용하는 것이 안전합니다.
#   * Action Mapping: 모델의 출력값은 보통 -1 ~ 1 사이의 수치입니다. 이를 실제 히터의 전압(V), 전류(mA), 혹은 PWM % 값으로 변환하는 매핑 로직이 send_control_signal에 필요합니다.
#
# ** 모터 제어 **
#
# * 학습된 BC-PPO 모델의 예측값(Action)을 받아 실제 모터의 RPM 제어 신호로 변환하고, 이를 장비(모터 드라이버 등)에 전달하는 과정을 포함한 최종 제어 루프입니다.
# * 보통 산업용 모터는 Modbus TCP나 0~10V 아날로그 신호 등을 사용하므로, 이를 모사한 변환 로직을 apply_motor_control 함수에 추가했습니다.
# * 코드 핵심 포인트
#   * RPM Delta 제어: 모델의 출력을 절대적 RPM 값이 아닌 변화량(rpm_delta)으로 사용했습니다. 이는 모터에 급격한 부하가 걸리는 것을 방지하고 부드러운 가속/감속을 가능하게 합니다.
#   * Hard Clipping: np.clip을 사용하여 모델이 실수로 장비의 물리적 한계(500~3000 RPM)를 넘는 명령을 내려도 안전하게 차단합니다.
# Global State 유지: CURRENT_MOTOR_RPM을 추적하여 현재 상태를 기준으로 다음 제어량을 결정하도록 설계했습니다.

# %%
import time
import numpy as np
from stable_baselines3 import PPO

# 1. 학습된 모델 로드
model = PPO.load("bc_ppo_oven_model")

# [설정] 모터 사양 및 제어 범위
MIN_RPM = 500
MAX_RPM = 3000
CURRENT_MOTOR_RPM = 1500  # 초기 가동 RPM

def read_external_sensors():
    """
    외부 센서로부터 현재 상태를 읽어옴 (예시 데이터)
    순서: [internal_temp, humidity, weight, surface_temp, fan_rpm, air_pressure]
    """
    # 실제 환경에서는 PLC/센서 API 호출 결과가 들어감
    return np.array([79.2, 30.1, 4900.5, 76.0, CURRENT_MOTOR_RPM, 14.5], dtype=np.float32)

def apply_motor_control(fan_action):
    """
    모델의 Action(-1 ~ 1)을 실제 모터 RPM 값으로 변환하여 전송
    """
    global CURRENT_MOTOR_RPM
    
    # 1. Action(-1 ~ 1)을 RPM 변화량으로 매핑 (예: 한 번에 최대 200 RPM 증감)
    rpm_delta = fan_action * 200
    
    # 2. 새로운 목표 RPM 계산 및 하드웨어 제한(Limit) 적용
    target_rpm = np.clip(CURRENT_MOTOR_RPM + rpm_delta, MIN_RPM, MAX_RPM)
    
    # 3. 실제 모터 드라이버에 명령 전달 (예: Modbus Write 또는 DAC 출력)
    # write_to_motor_driver(target_rpm) # 실제 통신 함수 가정
    
    CURRENT_MOTOR_RPM = target_rpm # 현재 상태 업데이트
    return target_rpm

def apply_heater_control(heater_action):
    """히터 제어 신호 변환 (예: 0~100% PWM)"""
    heater_power = np.clip((heater_action + 1) * 50, 0, 100)
    # write_to_heater_relay(heater_power)
    return heater_power

# 2. 실시간 제어 루프
print("--- Drying Oven AI-Driven Motor & Heater Control Start ---")

try:
    while True:
        # (1) 센서 데이터 수집
        obs = read_external_sensors()
        
        # (2) 모델 추론 (Deterministic=True로 안정성 확보)
        # obs shape: (6,) -> (1, 6)으로 모델 입력
        action, _ = model.predict(obs, deterministic=True)
        
        # action[0]: 히터 제어, action[1]: 팬(풍압) 제어
        h_action, f_action = action[0], action[1]
        
        # (3) 하드웨어 제어 명령 실행
        target_rpm = apply_motor_control(f_action)
        heater_pwr = apply_heater_control(h_action)
        
        # (4) 모니터링 출력
        print(f"[상태] 온도: {obs[0]:.1f}°C | 풍압: {obs[5]:.2f}Pa")
        print(f"[제어] 목표 RPM: {target_rpm:.0f} | 히터: {heater_pwr:.1f}%")
        print("-" * 40)
        
        # 제어 주기 (예: 2초마다 갱신)
        time.sleep(2.0)

except KeyboardInterrupt:
    print("\n--- 시스템 안전 종료 및 모터 정지 ---")
    # apply_motor_control(-1) # 모터 최소화 또는 정지 로직
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 6
#       3 from stable_baselines3 import PPO
#       5 # 1. 학습된 모델 로드
# ----> 6 model = PPO.load("bc_ppo_oven_model")
#       8 # [설정] 모터 사양 및 제어 범위
#       9 MIN_RPM = 500
#
# File ~/work/mlops_jupyter_nodebooks/jupyter_venv/lib/python3.12/site-packages/stable_baselines3/common/base_class.py:677, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     674     print("== CURRENT SYSTEM INFO ==")
#     675     get_system_info()
# --> 677 data, params, pytorch_variables = load_from_zip_file(
#     678     path,
#     679     device=device,
#     680     custom_objects=custom_objects,
#     681     print_system_info=print_system_info,
#     682 )
#     684 assert data is not None, "No data found in the saved file"
#     685 assert params is not None, "No params found in the saved file"
#
# File ~/work/mlops_jupyter_nodebooks/jupyter_venv/lib/python3.12/site-packages/stable_baselines3/common/save_util.py:402, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     375 def load_from_zip_file(
#     376     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     377     load_data: bool = True,
#    (...)    381     print_system_info: bool = False,
#     382 ) -> Tuple[Optional[Dict[str, Any]], TensorDict, Optional[TensorDict]]:
#     383     """
#     384     Load model data from a .zip archive
#     385
#    (...)    400         and dict of pytorch variables
#     401     """
# --> 402     file = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     404     # set device to cpu if cuda is not available
#     405     device = get_device(device=device)
#
# File /usr/lib/python3.12/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/work/mlops_jupyter_nodebooks/jupyter_venv/lib/python3.12/site-packages/stable_baselines3/common/save_util.py:239, in open_path_str(path, mode, verbose, suffix)
#     224 @open_path.register(str)
#     225 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     226     """
#     227     Open a path given by a string. If writing to the path, the function ensures
#     228     that the path exists.
#    (...)    237     :return:
#     238     """
# --> 239     return open_path_pathlib(pathlib.Path(path), mode, verbose, suffix)
#
# File ~/work/mlops_jupyter_nodebooks/jupyter_venv/lib/python3.12/site-packages/stable_baselines3/common/save_util.py:290, in open_path_pathlib(path, mode, verbose, suffix)
#     284         path.parent.mkdir(exist_ok=True, parents=True)
#     286 # if opening was successful uses the open_path() function
#     287 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     288 #   with corrections
#     289 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 290 return open_path_pathlib(path, mode, verbose, suffix)
#
# File ~/work/mlops_jupyter_nodebooks/jupyter_venv/lib/python3.12/site-packages/stable_baselines3/common/save_util.py:271, in open_path_pathlib(path, mode, verbose, suffix)
#     269             path, suffix = newpath, None
#     270         else:
# --> 271             raise error
#     272 else:
#     273     try:
#
# File ~/work/mlops_jupyter_nodebooks/jupyter_venv/lib/python3.12/site-packages/stable_baselines3/common/save_util.py:263, in open_path_pathlib(path, mode, verbose, suffix)
#     261 if mode == "r":
#     262     try:
# --> 263         return open_path(path.open("rb"), mode, verbose, suffix)
#     264     except FileNotFoundError as error:
#     265         if suffix is not None and suffix != "":
#
# File /usr/lib/python3.12/pathlib.py:1015, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1013 if "b" not in mode:
#    1014     encoding = io.text_encoding(encoding)
# -> 1015 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bc_ppo_oven_model.zip'
