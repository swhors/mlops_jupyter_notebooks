# %%
# !python -m pip install gymnasium stable_baselines3
# Out:
# Requirement already satisfied: gymnasium in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (1.2.3)
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy>=1.21.0 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from gymnasium) (2.4.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from stable_baselines3) (2.10.0)
# Requirement already satisfied: pandas in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from stable_baselines3) (3.0.1)
# Requirement already satisfied: matplotlib in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from stable_baselines3) (3.10.8)
# Requirement already satisfied: filelock in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.25.2)
# Requirement already satisfied: setuptools in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch<3.0,>=2.3->stable_baselines3) (1.4.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (26.0)
# Requirement already satisfied: pillow>=8 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from matplotlib->stable_baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/simpson/work/mlops_backend/venv/lib/python3.12/site-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.3)
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 4.3 MB/s eta 0:00:0000:01
# Installing collected packages: stable_baselines3
# Successfully installed stable_baselines3-2.7.1

# %% [markdown]
# 실제 장비와의 **통신 인터페이스(Modbus/MQTT 가상 예시)**, **시간대별 목표 온도 스케줄링**, 그리고 **성능 리포트 자동 생성** 기능을 모두 통합한 최종 마스터 코드입니다.
#
# 이 코드는 `REAL_MODE` 변수에 따라 **가상 시뮬레이션 학습**과 **실제 장비 제어**를 자유롭게 전환할 수 있도록 설계되었습니다.
#
# #### **1. 통합 제어 및 리포트 시스템 코드**

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from collections import deque
import time

# [설정] 실제 장비 연결 여부 (True: 장비 제어, False: 시뮬레이션 학습)
REAL_MODE = False

# %%
class IntegratedDryerEnv(gym.Env):
    def __init__(self):
        super(IntegratedDryerEnv, self).__init__()
        # 액션: [히터 0:Off/1:On, 압력 0:유지/1:증가/2:감소]
        self.action_space = spaces.MultiDiscrete([2, 3])
        # 상태: [현재온도, 오차, 현재압력, 온도변화율]
        self.observation_space = spaces.Box(low=-150, high=150, shape=(4,), dtype=np.float32)
        
        # 1. 스케줄링 설정 (분 단위 또는 스텝 단위)
        # 0~100스텝: 50도, 101~200스텝: 80도, 201~300스텝: 60도
        self.schedule = {100: 50.0, 200: 80.0, 300: 60.0}
        self.history = deque([(0, 0.5)] * 5, maxlen=5) # 5스텝 열지연
        self.reset()

    def _get_target_temp(self):
        for limit, temp in sorted(self.schedule.items()):
            if self.steps <= limit: return temp
        return 60.0

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.steps = 0
        self.pressure = 0.5
        self.current_temp = 30.0 if not REAL_MODE else self._read_real_sensor()
        self.target_temp = self._get_target_temp()
        return self._get_obs(), {}

    def _get_obs(self):
        diff = self.current_temp - self.target_temp
        return np.array([self.current_temp, diff, self.pressure, 0.0], dtype=np.float32)

    def _read_real_sensor(self):
        # [실제 장비 연동] Modbus/MQTT 등으로 온도 읽기
        # return modbus_client.read_input_registers(0x01)
        return 30.0 # 예시값

    def _send_real_command(self, h, p):
        # [실제 장비 연동] PLC 등에 제어 명령 송신
        # modbus_client.write_register(0x02, h)
        pass

    def step(self, actions):
        self.steps += 1
        self.target_temp = self._get_target_temp()
        self.history.append(actions)
        h_act, p_act = self.history[0] # 지연된 액션 적용

        if REAL_MODE:
            self._send_real_command(h_act, p_act)
            time.sleep(1) # 제어 주기 맞춤
            self.current_temp = self._read_real_sensor()
        else:
            # 시뮬레이션 물리 엔진
            if p_act == 1: self.pressure = min(1.0, self.pressure + 0.02)
            elif p_act == 2: self.pressure = max(0.0, self.pressure - 0.02)
            heat = 4.2 if h_act == 1 else 0.0
            cool = self.pressure * 6.0
            self.current_temp += (heat - cool - (self.current_temp-20)*0.03) + np.random.normal(0, 0.05)

        diff = abs(self.current_temp - self.target_temp)
        reward = 5.0 if diff < 0.5 else 1.0 - (diff * 0.2)
        
        terminated = self.steps >= 300
        return self._get_obs(), reward, terminated, False, {}

# %%
# [Step 2] 학습 및 저장 함수
def train_and_save(model_name="dryer_master_model"):
    env = IntegratedDryerEnv()
    model = PPO("MlpPolicy", env, verbose=1, learning_rate=0.0003)
    model.learn(total_timesteps=50000)
    model.save(model_name)
    return model

# %%
# [Step 3] 성능 리포트 생성 함수
def run_and_report(model_path):
    env = IntegratedDryerEnv()
    model = PPO.load(model_path)
    obs, _ = env.reset()
    
    logs = []
    for i in range(300):
        print(f'step [{i}]')
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, _ = env.step(action)
        logs.append({
            'Step': i, 'Target': env.target_temp, 'Current': obs[0], 
            'Error': abs(obs[1]), 'Pressure': env.pressure, 'Heater': action[0]
        })
    
    df = pd.DataFrame(logs)
    print(f"\n[성능 요약] MAE: {df['Error'].mean():.4f} | Max Error: {df['Error'].max():.4f}")
    
    # 시각화 리포트
    plt.figure(figsize=(15, 7))
    plt.plot(df['Target'], 'g--', label='Target Schedule')
    plt.plot(df['Current'], 'r-', label='AI Control Temp', linewidth=2)
    plt.bar(df.index, df['Heater']*5, alpha=0.2, color='orange', label='Heater On')
    plt.fill_between(df.index, 0, df['Pressure']*100, alpha=0.1, color='blue', label='Pressure %')
    plt.title("Dryer AI Control Performance Report (Lag & Schedule Applied)")
    plt.legend()
    plt.show()
    return df

# %%
# 실행
# 1. 학습 (최초 1회)
train_and_save("final_model")
print('completed to train and save model')
# 2. 리포트 생성 및 검증
report_data = run_and_report("final_model")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | -4.6e+03 |
# | time/              |          |
# |    fps             | 2404     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -4.32e+03   |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 2           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015420651 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | -0.00483    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 6.93e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | -3.9e+03     |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 3            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0113855405 |
# |    clip_fraction        | 0.098        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.00589      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36e+04     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00743     |
# |    value_loss           | 5.91e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -3.33e+03   |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 4           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013174477 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.0371      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0073     |
# |    value_loss           | 2.75e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -2.89e+03   |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 5           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016044185 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.42e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 1.01e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -2.63e+03   |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 6           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.030152103 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.98e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 5.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -2.44e+03   |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 7           |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017937455 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00923    |
# |    value_loss           | 8.99e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -2.22e+03   |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 8           |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012188682 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.0588      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 7.53e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | -2.04e+03  |
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 9          |
# |    time_elapsed         | 197        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01763035 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | -0.164     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 219        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00787   |
# |    value_loss           | 703        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -1.88e+03   |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 10          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008639665 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 783         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 1.66e+03    |
# -----------------------------------------
