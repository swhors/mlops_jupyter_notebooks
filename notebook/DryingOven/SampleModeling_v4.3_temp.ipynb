# %% [markdown]
# ## **_Sample Modeling V4.3_** (for Reinforcement Learning)
#
# * 이 페이지는 "Drying Oven"의 가상 센서 데이터를 이용하여 PPO 모델을 교육하고 예측하는 예제를 구현합니다.
# * PPO는 기본적으로 Linear 모델을 지원합니다.
# * pip install numpy pandas tensor ipykernel torch scikit-learn gymnasium stable_baselines3

# %%
# ----------------------------------------------------
# Global 변수 선언
# ----------------------------------------------------
import os
import sys
from pathlib import Path
from datetime import datetime

csv_file_pathname = lambda: f".{os.sep}data{os.sep}ppolstm_dryer_sensor_v4.3_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
model_path_name = lambda: f".{os.sep}model{os.sep}ppolstm_dryer_v4.3_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pth"
global_num_samples = 1024
parent_dir = os.path.dirname(os.getcwd())
project_home_dir = str(Path.cwd().parent.parent)
venv_name = "samplemodelingv4_3"

reward_gen_fn="lib/reward/dryer_oven/gen_reward_v1.py"
reward_gen_fn = reward_gen_fn.replace("/", os.sep)
reward_gen_fn_pythonfile = project_home_dir + os.sep + reward_gen_fn
simulation_cls_pathname = "lib/simulate/dryer_oven_simulation.py"
simulation_cls_pathname = simulation_cls_pathname.replace("/", os.sep)
simulation_cls_pathname = project_home_dir + os.sep + simulation_cls_pathname

# %%
# ----------------------------------------------------
# 개발 환경 초기화
# 한 번만 호출하여 주십시요.


# 1.1 set pythonpath to import from parent directory
def _init_environ():
    python_path = os.environ.get("PYTHONPATH")
    if python_path is None:
        python_path = ""
    sys.path.append(parent_dir)
    sys.path.append(project_home_dir)
    python_lib_path = [
        f'{project_home_dir}{os.sep}{venv_name}{os.sep}{"Lib" if sys.platform == "win32" else "lib"}{os.sep}site-packages',
        project_home_dir,
        python_path
    ]
    os.environ["PYTHONPATH"] = ";".join(python_lib_path)

    os.environ["CLEARML_WEB_HOST"] = "http://172.16.8.168:8080/"
    os.environ["CLEARML_API_HOST"] = "http://172.16.8.168:8008/"
    os.environ["CLEARML_FILES_HOST"] = "http://172.16.8.168:8081"
    os.environ["CLEARML_API_ACCESS_KEY"] = "SIJ8V8YP9PL25YEAVAWGP9NV11TMOQ"
    os.environ["CLEARML_API_SECRET_KEY"] = "6x_MEHvgrUv9-TFFDrE9BE7vb3JYOXDWq4kQtqbd58nQ5pqHEGMt6qQXxF7_HCyzq7E"

_init_environ()

# %%
# !echo $PYTHONPATH
from lib.simulate.genetate_data import generate_data_v1

# 1. 설정값 초기화
num_samples = global_num_samples
target_temp = 80
initial_temp = 25
# drop_envs = [(0.4, 100, 30), (0.5, 200, 40)]
# spike_envs = [(0.6, 300, 30), (0.7, 200, 40), (0.8, 200, 70)]
drop_envs = []
spike_envs = []

verbose = 0


stored_data_file_pathname = generate_data_v1(drop_envs=drop_envs,
                                             spike_envs=spike_envs,
                                             csv_file_pathname=csv_file_pathname(),
                                             num_samples=global_num_samples,
                                             target_temp=target_temp,
                                             initial_temp=initial_temp,
                                             verbose=verbose)
print(f"Data stored in: {stored_data_file_pathname}")
# Out:
# /home/simpson/work/mlops_jupyter_notebooks_simpson/samplemodelingv4_3/lib/site-packages;/home/simpson/work/mlops_jupyter_notebooks_simpson;/home/simpson/work/mlops_jupyter_notebooks_simpson/samplemodelingv4_3/lib/site-packages;/home/simpson/work/mlops_jupyter_notebooks_simpson;/home/simpson/work/mlops_jupyter_notebooks_simpson/samplemodelingv4_3/lib/site-packages;/home/simpson/work/mlops_jupyter_notebooks_simpson;
# Start to generate sample data. [2026-03-31 00:03:00.938305]
# End to generate sample data. [2026-03-31 00:03:00.949093]
# Data stored in: ./data/ppolstm_dryer_sensor_v4.3_20260331_000300.csv

# %% [markdown]
# #### Step 2 Env 생성

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from lib.module import _load_class_module as load_class
from lib.module import load_function


class DryerEnv(gym.Env):
    """
    RecurrentPPO 학습을 위한 건조기 온도 제어 환경
    목표: 팬 RPM을 조절하여 내부 온도를 80도로 유지하기
    """
    init_sim_data = [{
            "timestamp": 0.0,
            "inner_temp": 79.5,  # 실측 온도
            "error": -0.5,       # 실측 온도 - 목표 온도
            "humidity": 45.2,    # 실측 습도
            "weight": 4.65,      # 실측 무게
            "outer_temp": 22.1,
            "pressure": 1012.8,
            "fan_rpm": 1550.0,
            "user_action": 0
        },
        {
            "timestamp": 0.0,
            "inner_temp": 25,  # 실측 온도
            "error": -55,      # 실측 온도 - 목표 온도
            "humidity": 80,    # 실측 습도
            "weight": 5.0,     # 실측 무게
            "outer_temp": 22.0,
            "pressure": 1013.0,
            "fan_rpm": 1500.0,
            "user_action": 2
        }
    ]

    OVER_TEMP_LIMIT=15.0

    def __init__(self, reward_gen_fn_pathname=None, is_simulatation=True, simulation_cls_pahname=None, debug=False):
        """
        ; params reward_gen_fn: str, 보상 계산을 위한 사용자 정의 함수 (선택적)
        ' params is_simulation: boolean, 시뮬레이션 모드 여부 (True: 시뮬레이터, False: 실제 환경)
        """
        super().__init__()

        # 1. Action Space: [0: DOWN, 1: KEEP, 2: UP]
        self.action_space = spaces.Discrete(3)

        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(8,), dtype=np.float32
        )        
        self.is_simulation = is_simulatation
        self._debug = debug
        self.target_temp = 80.0
        self.max_steps = 10000
        self.state = []
        self.terminated = False
        self.current_step = 0
        self.prev_inner_temp = None  # 이전 온도 저장용
        self.truncated = False
        self.simulation_cls_pahname: str = simulation_cls_pahname
        self.simulation_cls = load_class(self.simulation_cls_pahname)(debug=False) if self.simulation_cls_pahname else None
        self.reward_gen_fn_pathname: str = reward_gen_fn_pathname
        self.reward_gen_fn = load_function(self.reward_gen_fn_pathname, "generate_reward") if self.reward_gen_fn_pathname else None
        self.reset()

    def _send_action_to_dryer(self, action):
        """
        건조기 하드웨어로 제어 신호(RPM 조절)를 전송하는 함수
        실제 환경에서는 MQTT publish나 API POST 요청이 들어갑니다.
        """
        action_map = {0: "DOWN", 1: "KEEP", 2: "UP"}
        command = action_map[action]
        # 예시: requests.post(f"http://dryer-ip/control", json={"action": command})
        # print(f"[Hardware] Sent command: {command} to {self.device_id}")
        pass

    def _get_data_from_dryer(self, action):
        """
        건조기 센서로부터 실측 데이터를 읽어오는 함수
        실제 환경에서는 센서 API 호출이나 DB 조회가 들어갑니다.
        """
        # 예시: response = requests.get(f"http://dryer-ip/sensors").json()
        # 가상의 실측 데이터 구조 (API 응답 가정)
        if self.is_simulation:
            if len(self.state) == 8 and self.simulation_cls is not None:
                real_measured_data = self.simulation_cls.step(action = action, state = self.state)
            else:
                real_measured_data = DryerEnv.init_sim_data[1]
        else:
            ## 실제 상황에서는 건조기에서 데이터를 가져와야 합니다. 
            real_measured_data = DryerEnv.init_sim_data[0]
            
        return np.array([real_measured_data["timestamp"],
                         real_measured_data["inner_temp"],
                         real_measured_data["error"],
                         real_measured_data["humidity"],
                         real_measured_data["weight"],
                         real_measured_data["outer_temp"],
                         real_measured_data["pressure"],
                         real_measured_data["fan_rpm"]],
                         dtype=np.float32)

    def reset(self, seed=None, options=None, is_gen_data=True):
        super().reset(seed=seed)
        self.current_step = 0
        if self.terminated:
            pre_user_action = 0
        else:
            pre_user_action = 1
        if self._debug:
            print(f'DryerEnv.rest()')
        if is_gen_data:
            self.state = self._get_data_from_dryer(action=pre_user_action)
        else:
            self.state = None
        self.terminated = False
        self.truncated = False
        self.prev_inner_temp = None
        return self.state, {}
    
    @staticmethod
    def _unpack_nptype(np_value):
        import numpy
        if isinstance(np_value, (numpy.float32, numpy.float64, np.float32, np.float64,
                                 numpy.int32, numpy.int64, np.int32, np.int64,
                                 numpy.ndarray, np.ndarray)):
            return np_value.item()
        return np_value

    def _generate_reward_default(self, current_temp, action):
        """
        # 보상(Reward)
        ; params inner_temp;
        ; return reward, terminated, truncated
        """
        diff = current_temp - self.target_temp
        reward = -abs(np.diff)
    
        # 올바른 대응에 보너스
        if np.diff < -1.0 and action == 0: reward += 20.0 # 추울 때 RPM 낮추면 칭찬
        if diff > 1.0 and action == 2:  reward += 20.0 # 더울 때 RPM 높이면 칭찬
        # 목표 온도 근처(±2도)에 도달 시 추가 보상
        if abs(diff) <= 1.0:
            reward += 30.0

        # if diff > 1.0: # 온도가 높음
        #     reward += (20.0 if action == 2 else -30.0) # UP이면 상, DOWN/KEEP이면 큰 벌

        # 4. 종료 조건
        terminated = self.current_step >= self.max_steps
        truncated = False
        # 온도가 너무 높거나 낮아지면 에피소드 조기 종료 (Safety)
        max_allow_temp = DryerEnv.OVER_TEMP_LIMIT + self.target_temp
        min_allow_temp = DryerEnv.OVER_TEMP_LIMIT
        if current_temp > max_allow_temp or current_temp < min_allow_temp:
            terminated = True
            reward -= 100
        return reward, terminated, truncated

    def _generate_reward(self, inner_temp, action):
        if self.reward_gen_fn:
            return self.reward_gen_fn(inner_temp=inner_temp,
                                      action=action,
                                      prev_inner_temp=self.prev_inner_temp,
                                      target_temp=self.target_temp,
                                      temp_limit_depth=DryerEnv.OVER_TEMP_LIMIT)
        if self._debug > 0:
            print("No reward generation function provided.")
        return self._generate_reward_default(current_temp=inner_temp, action=action)
    
    def _check_terminate(self, inner_temp, reward, max_steps, current_step):
        """
        4. 종료 조건
        """
        # 온도가 너무 높거나 낮아지면 에피소드 조기 종료 (Safety)
        terminated = False
        if inner_temp > 90 or inner_temp < 15:
            terminated = True
            reward -= 100
    
        if current_step > max_steps:
            terminated = True
        
        truncated = False
        return reward, terminated, truncated
    
    def _load_observation(self, action: int = 1, current_step: int = 0):
        # 실제 환경에서는 센서 데이터를 읽어와서 self.state를 업데이트해야 합니다.
        # 예시: self.state = self._get_data_from_dryer(action=self.pre_user_action)
        return self._get_data_from_dryer(action=action)

    def step(self, action):
        self.current_step += 1

        action = DryerEnv._unpack_nptype(action)
        # print(f'self.state #-1 = {self.state}, {action}[{type(action)}]')        
        self._send_action_to_dryer(action)

        if self.current_step > self.max_steps:
            self.current_step = self.max_steps # 인덱스 초과 방지

        # print(f'self.state #0 = {self.state}')
        self.state = self._load_observation(action=action,current_step=self.current_step)

        for i in range(len(self.state)):
            self.state[i] = DryerEnv._unpack_nptype(self.state[i])

        inner_temp_pos = 1
        inner_temp = self.state[inner_temp_pos]
        # 5. 보상 계산
        reward = self._generate_reward(inner_temp=inner_temp, action=action)

        # 4. 종료 조건
        reward, self.terminated, self.truncated = self._check_terminate(inner_temp=inner_temp,
                                                                        reward=reward,
                                                                        max_steps=self.max_steps,
                                                                        current_step=self.current_step)
        # 5. 다음 스텝을 위해 현재 온도와 action을 저장
        self.pre_user_action = 0 if self.terminated else action
        self.prev_inner_temp = inner_temp
        return self.state, reward, self.terminated, self.truncated, {}


# 환경 테스트
if __name__ == "__main__":
    env = DryerEnv(reward_gen_fn_pathname=reward_gen_fn_pythonfile,
                   is_simulatation=True,
                   simulation_cls_pahname=simulation_cls_pathname)
    obs, _ = env.reset()
    print(f"Initial Obs: {obs}")
    
    # 랜덤 액션 테스트
    for i in range(10):
        action = env.action_space.sample()
        in_temp = obs[1]
        obs, reward, done, _, _ = env.step(action)
        print(f"[{i:03d}] Action: {action}, In Temp: {in_temp:.2f}, Out Temp: {obs[1]:.2f}, Reward: {reward:.2f}")
# Out:
# module_path_name = /home/simpson/work/mlops_jupyter_notebooks_simpson/lib/simulate/dryer_oven_simulation.py
# ModuleSpec(name='classname', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fa876174200>, origin='/home/simpson/work/mlops_jupyter_notebooks_simpson/lib/simulate/dryer_oven_simulation.py') <class '_frozen_importlib.ModuleSpec'>
# Initial Obs: [   0.       34.7     -45.3      79.99      4.9999   22.     1013.
#  1500.    ]
# [000] Action: 1, In Temp: 34.70, Out Temp: 43.43, Reward: -1387.36
# [001] Action: 0, In Temp: 43.43, Out Temp: 51.43, Reward: -766.25
# [002] Action: 1, In Temp: 51.43, Out Temp: 58.68, Reward: -504.41
# [003] Action: 1, In Temp: 58.68, Out Temp: 65.26, Reward: -267.29
# [004] Action: 1, In Temp: 65.26, Out Temp: 71.22, Reward: -127.06
# [005] Action: 2, In Temp: 71.22, Out Temp: 76.30, Reward: -63.69
# [006] Action: 1, In Temp: 76.30, Out Temp: 80.87, Reward: 49.24
# [007] Action: 1, In Temp: 80.87, Out Temp: 84.98, Reward: -74.83
# [008] Action: 0, In Temp: 84.98, Out Temp: 89.10, Reward: -132.89
# [009] Action: 0, In Temp: 89.10, Out Temp: 93.29, Reward: -326.59

# %% [markdown]
# #### Step 3 모방 학습(Behavioral Cloning)으로 PPO 초기화하기

# %% [markdown]
# ##### Step 3.1 가상 데이터를 로딩하는 Env 작성

# %%
import gymnasium as gym
from gymnasium import spaces
import pandas as pd
import numpy as np

class CSVDataDryerEnv(DryerEnv):
    def __init__(self, csv_file, reward_gen_fn_pathname=None):
        # 데이터 로드
        self.df = pd.read_csv(csv_file)
        self.max_steps = len(self.df) - 1
        # super(CSVDataDryerEnv, self).__init__(reward_gen_fn_pathname=reward_gen_fn_pathname,
        #                                       is_simulatation=False)
        super().__init__(reward_gen_fn_pathname=reward_gen_fn_pathname, is_simulatation=False)

    def _load_observation(self, action: int = 1, current_step: int = 0):
        # CSV의 특정 행에서 데이터를 가져와서 state로 반환
        print(f'current_step = {current_step}, {len(self.df)}')
        row = self.df.iloc[current_step]
        return np.array([
            row['timestamp'],
            row['inner_temp'],
            row['inner_temp'] - self.target_temp,
            row['humidity'],
            row['weight'],
            row['outer_temp'],
            row['pressure'],
            row['fan_rpm']
        ], dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed, is_gen_data=False)
        self.state = self._load_observation(action=1, current_step=self.current_step)
        return self.state, {}

# %% [markdown]
# ##### 3.2 모방 학습 하기

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from sb3_contrib import RecurrentPPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor
# from lib.callback.ppo_event_callback import PPOEventCallback


cb_verbose = 1


def train_dryer_model_from_csv(model_path_name,
                               n_steps=128,
                               csv_path: str='dryer_virtual_data.csv',
                               reward_gen_fn_pathname=None,
                               n_epochs=1,
                               batch_size=64,
                               learn_repeat_cnt: int=5,
                               callback=None):
    # 1. CSV 기반 환경 생성
    base_env = CSVDataDryerEnv(csv_file=csv_path,
                               reward_gen_fn_pathname=reward_gen_fn_pathname)
    env = DummyVecEnv([lambda: base_env])
    # callback = PPOEventCallback(check_freq=20, cb_verbose=cb_verbose)

    # 2. 모델 설정 (Linear 기반 PPO)
    verbose = 0
    model = RecurrentPPO(
        "MlpLstmPolicy",
        env,
        verbose=verbose,
        n_steps=n_steps,    # 한 번의 업데이트를 위해 수집할 스텝 수
        batch_size=batch_size,      # 미니배치 크기
        ent_coef=0.1,        
        learning_rate=3e-4,
        n_epochs=n_epochs,  # 최적화 반복 횟수
        gamma=0.99,         # 할인율
        device="auto"       # GPU가 있다면 자동 할당
    )

    # 3. 학습 시작
    # CSV 데이터의 크기에 맞춰 학습 횟수를 조절하세요.
    print(f"{csv_path} 데이터를 기반으로 학습을 시작합니다...")
    if callback is not None:
        model.learn(total_timesteps=len(base_env.df) * learn_repeat_cnt,  # 데이터를 5번 반복 학습
                    callback=callback)
    else:
        model.learn(total_timesteps=len(base_env.df) * learn_repeat_cnt)  # 데이터를 5번 반복 학습

    trained_model_path_name = model_path_name()
    # 4. 저장
    model.save(trained_model_path_name)
    print("학습 및 모델 저장 완료")

    # 5. 성능 평가
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=5)
    print(f"평균 보상: {mean_reward:.2f} +/- {std_reward:.2f}")
    
    return model, trained_model_path_name

n_steps = 128
learn_repeat_cnt = 1
# 학습 실행
# checkpoint_callback = CheckpointCallback(save_freq=5000, save_path='./logs/', name_prefix='dryer_model')
# trained_model = train_dryer_model(model_path_name=model_path_name, total_timesteps=10000, n_epochs=1)
print(f"Trained will start. [{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}]")

trained_model, trained_model_path_name = train_dryer_model_from_csv(model_path_name=model_path_name,
                                                                    n_steps=n_steps,
                                                                    batch_size=10,
                                                                    csv_path=stored_data_file_pathname,
                                                                    reward_gen_fn_pathname=reward_gen_fn_pythonfile,
                                                                    learn_repeat_cnt=learn_repeat_cnt)
print(f"Trained model saved at: {trained_model_path_name}")
# Out:
# Trained will start. [2026-03-31 00:03:08]
# current_step = 0, 1024
# ./data/ppolstm_dryer_sensor_v4.3_20260331_000300.csv 데이터를 기반으로 학습을 시작합니다...
# current_step = 0, 1024
# current_step = 1, 1024
# current_step = 2, 1024
# current_step = 3, 1024
# current_step = 4, 1024
# current_step = 5, 1024
# current_step = 6, 1024
# current_step = 7, 1024
# current_step = 8, 1024
# current_step = 9, 1024
# current_step = 10, 1024
# current_step = 11, 1024
# current_step = 12, 1024
# current_step = 13, 1024
# current_step = 14, 1024
# current_step = 15, 1024
# current_step = 16, 1024
# current_step = 17, 1024
# current_step = 18, 1024
# current_step = 19, 1024
# current_step = 20, 1024
# current_step = 21, 1024
# current_step = 22, 1024
# current_step = 23, 1024
# current_step = 24, 1024
# current_step = 25, 1024
# current_step = 26, 1024
# current_step = 27, 1024
# current_step = 28, 1024
# current_step = 29, 1024
# current_step = 30, 1024
# current_step = 31, 1024
# current_step = 32, 1024
# current_step = 33, 1024
# current_step = 34, 1024
# current_step = 35, 1024
# current_step = 36, 1024
# current_step = 37, 1024
# current_step = 38, 1024
# current_step = 39, 1024
# current_step = 40, 1024
# current_step = 41, 1024
# current_step = 42, 1024
# current_step = 43, 1024
# current_step = 44, 1024
# current_step = 45, 1024
# current_step = 46, 1024
# current_step = 47, 1024
# current_step = 48, 1024
# current_step = 49, 1024
# current_step = 50, 1024
# current_step = 51, 1024
# current_step = 52, 1024
# current_step = 53, 1024
# current_step = 54, 1024
# current_step = 55, 1024
# current_step = 56, 1024
# current_step = 57, 1024
# current_step = 58, 1024
# current_step = 59, 1024
# current_step = 60, 1024
# current_step = 61, 1024
# current_step = 62, 1024
# current_step = 63, 1024
# current_step = 64, 1024
# current_step = 65, 1024
# current_step = 66, 1024
# current_step = 67, 1024
# current_step = 68, 1024
# current_step = 69, 1024
# current_step = 70, 1024
# current_step = 71, 1024
# current_step = 72, 1024
# current_step = 73, 1024
# current_step = 74, 1024
# current_step = 75, 1024
# current_step = 76, 1024
# current_step = 77, 1024
# current_step = 78, 1024
# current_step = 79, 1024
# current_step = 80, 1024
# current_step = 81, 1024
# current_step = 82, 1024
# current_step = 83, 1024
# current_step = 84, 1024
# current_step = 85, 1024
# current_step = 86, 1024
# current_step = 87, 1024
# current_step = 88, 1024
# current_step = 89, 1024
# current_step = 90, 1024
# current_step = 91, 1024
# current_step = 92, 1024
# current_step = 93, 1024
# current_step = 94, 1024
# current_step = 95, 1024
# current_step = 96, 1024
# current_step = 97, 1024
# current_step = 98, 1024
# current_step = 99, 1024
# current_step = 100, 1024
# current_step = 101, 1024
# current_step = 102, 1024
# current_step = 103, 1024
# current_step = 104, 1024
# current_step = 105, 1024
# current_step = 106, 1024
# current_step = 107, 1024
# current_step = 108, 1024
# current_step = 109, 1024
# current_step = 110, 1024
# current_step = 111, 1024
# current_step = 112, 1024
# current_step = 113, 1024
# current_step = 114, 1024
# current_step = 115, 1024
# current_step = 116, 1024
# current_step = 117, 1024
# current_step = 118, 1024
# current_step = 119, 1024
# current_step = 120, 1024
# current_step = 121, 1024
# current_step = 122, 1024
# current_step = 123, 1024
# current_step = 124, 1024
# current_step = 125, 1024
# current_step = 126, 1024
# current_step = 127, 1024
# current_step = 128, 1024
# current_step = 129, 1024
# current_step = 130, 1024
# current_step = 131, 1024
# current_step = 132, 1024
# current_step = 133, 1024
# current_step = 134, 1024
# current_step = 135, 1024
# current_step = 136, 1024
# current_step = 137, 1024
# current_step = 138, 1024
# current_step = 139, 1024
# current_step = 140, 1024
# current_step = 141, 1024
# current_step = 142, 1024
# current_step = 143, 1024
# current_step = 144, 1024
# current_step = 145, 1024
# current_step = 146, 1024
# current_step = 147, 1024
# current_step = 148, 1024
# current_step = 149, 1024
# current_step = 150, 1024
# current_step = 151, 1024
# current_step = 152, 1024
# current_step = 153, 1024
# current_step = 154, 1024
# current_step = 155, 1024
# current_step = 156, 1024
# current_step = 157, 1024
# current_step = 158, 1024
# current_step = 159, 1024
# current_step = 160, 1024
# current_step = 161, 1024
# current_step = 162, 1024
# current_step = 163, 1024
# current_step = 164, 1024
# current_step = 165, 1024
# current_step = 166, 1024
# current_step = 167, 1024
# current_step = 168, 1024
# current_step = 169, 1024
# current_step = 170, 1024
# current_step = 171, 1024
# current_step = 172, 1024
# current_step = 173, 1024
# current_step = 174, 1024
# current_step = 175, 1024
# current_step = 176, 1024
# current_step = 177, 1024
# current_step = 178, 1024
# current_step = 179, 1024
# current_step = 180, 1024
# current_step = 181, 1024
# current_step = 182, 1024
# current_step = 183, 1024
# current_step = 184, 1024
# current_step = 185, 1024
# current_step = 186, 1024
# current_step = 187, 1024
# current_step = 188, 1024
# current_step = 189, 1024
# current_step = 190, 1024
# current_step = 191, 1024
# current_step = 192, 1024
# current_step = 193, 1024
# current_step = 194, 1024
# current_step = 195, 1024
# current_step = 196, 1024
# current_step = 197, 1024
# current_step = 198, 1024
# current_step = 199, 1024
# current_step = 200, 1024
# current_step = 201, 1024
# current_step = 202, 1024
# current_step = 203, 1024
# current_step = 204, 1024
# current_step = 205, 1024
# current_step = 206, 1024
# current_step = 207, 1024
# current_step = 208, 1024
# current_step = 209, 1024
# current_step = 210, 1024
# current_step = 211, 1024
# current_step = 212, 1024
# current_step = 213, 1024
# current_step = 214, 1024
# current_step = 215, 1024
# current_step = 216, 1024
# current_step = 217, 1024
# current_step = 218, 1024
# current_step = 219, 1024
# current_step = 220, 1024
# current_step = 221, 1024
# current_step = 222, 1024
# current_step = 223, 1024
# current_step = 224, 1024
# current_step = 225, 1024
# current_step = 226, 1024
# current_step = 227, 1024
# current_step = 228, 1024
# current_step = 229, 1024
# current_step = 230, 1024
# current_step = 231, 1024
# current_step = 232, 1024
# current_step = 233, 1024
# current_step = 234, 1024
# current_step = 235, 1024
# current_step = 236, 1024
# current_step = 237, 1024
# current_step = 238, 1024
# current_step = 239, 1024
# current_step = 240, 1024
# current_step = 241, 1024
# current_step = 242, 1024
# current_step = 243, 1024
# current_step = 244, 1024
# current_step = 245, 1024
# current_step = 246, 1024
# current_step = 247, 1024
# current_step = 248, 1024
# current_step = 249, 1024
# current_step = 250, 1024
# current_step = 251, 1024
# current_step = 252, 1024
# current_step = 253, 1024
# current_step = 254, 1024
# current_step = 255, 1024
# current_step = 256, 1024
# current_step = 257, 1024
# current_step = 258, 1024
# current_step = 259, 1024
# current_step = 260, 1024
# current_step = 261, 1024
# current_step = 262, 1024
# current_step = 263, 1024
# current_step = 264, 1024
# current_step = 265, 1024
# current_step = 266, 1024
# current_step = 267, 1024
# current_step = 268, 1024
# current_step = 269, 1024
# current_step = 270, 1024
# current_step = 271, 1024
# current_step = 272, 1024
# current_step = 273, 1024
# current_step = 274, 1024
# current_step = 275, 1024
# current_step = 276, 1024
# current_step = 277, 1024
# current_step = 278, 1024
# current_step = 279, 1024
# current_step = 280, 1024
# current_step = 281, 1024
# current_step = 282, 1024
# current_step = 283, 1024
# current_step = 284, 1024
# current_step = 285, 1024
# current_step = 286, 1024
# current_step = 287, 1024
# current_step = 288, 1024
# current_step = 289, 1024
# current_step = 290, 1024
# current_step = 291, 1024
# current_step = 292, 1024
# current_step = 293, 1024
# current_step = 294, 1024
# current_step = 295, 1024
# current_step = 296, 1024
# current_step = 297, 1024
# current_step = 298, 1024
# current_step = 299, 1024
# current_step = 300, 1024
# current_step = 301, 1024
# current_step = 302, 1024
# current_step = 303, 1024
# current_step = 304, 1024
# current_step = 305, 1024
# current_step = 306, 1024
# current_step = 307, 1024
# current_step = 308, 1024
# current_step = 309, 1024
# current_step = 310, 1024
# current_step = 311, 1024
# current_step = 312, 1024
# current_step = 313, 1024
# current_step = 314, 1024
# current_step = 315, 1024
# current_step = 316, 1024
# current_step = 317, 1024
# current_step = 318, 1024
# current_step = 319, 1024
# current_step = 320, 1024
# current_step = 321, 1024
# current_step = 322, 1024
# current_step = 323, 1024
# current_step = 324, 1024
# current_step = 325, 1024
# current_step = 326, 1024
# current_step = 327, 1024
# current_step = 328, 1024
# current_step = 329, 1024
# current_step = 330, 1024
# current_step = 331, 1024
# current_step = 332, 1024
# current_step = 333, 1024
# current_step = 334, 1024
# current_step = 335, 1024
# current_step = 336, 1024
# current_step = 337, 1024
# current_step = 338, 1024
# current_step = 339, 1024
# current_step = 340, 1024
# current_step = 341, 1024
# current_step = 342, 1024
# current_step = 343, 1024
# current_step = 344, 1024
# current_step = 345, 1024
# current_step = 346, 1024
# current_step = 347, 1024
# current_step = 348, 1024
# current_step = 349, 1024
# current_step = 350, 1024
# current_step = 351, 1024
# current_step = 352, 1024
# current_step = 353, 1024
# current_step = 354, 1024
# current_step = 355, 1024
# current_step = 356, 1024
# current_step = 357, 1024
# current_step = 358, 1024
# current_step = 359, 1024
# current_step = 360, 1024
# current_step = 361, 1024
# current_step = 362, 1024
# current_step = 363, 1024
# current_step = 364, 1024
# current_step = 365, 1024
# current_step = 366, 1024
# current_step = 367, 1024
# current_step = 368, 1024
# current_step = 369, 1024
# current_step = 370, 1024
# current_step = 371, 1024
# current_step = 372, 1024
# current_step = 373, 1024
# current_step = 374, 1024
# current_step = 375, 1024
# current_step = 376, 1024
# current_step = 377, 1024
# current_step = 378, 1024
# current_step = 379, 1024
# current_step = 380, 1024
# current_step = 381, 1024
# current_step = 382, 1024
# current_step = 383, 1024
# current_step = 384, 1024
# current_step = 385, 1024
# current_step = 386, 1024
# current_step = 387, 1024
# current_step = 388, 1024
# current_step = 389, 1024
# current_step = 390, 1024
# current_step = 391, 1024
# current_step = 392, 1024
# current_step = 393, 1024
# current_step = 394, 1024
# current_step = 395, 1024
# current_step = 396, 1024
# current_step = 397, 1024
# current_step = 398, 1024
# current_step = 399, 1024
# current_step = 400, 1024
# current_step = 401, 1024
# current_step = 402, 1024
# current_step = 403, 1024
# current_step = 404, 1024
# current_step = 405, 1024
# current_step = 406, 1024
# current_step = 407, 1024
# current_step = 408, 1024
# current_step = 409, 1024
# current_step = 410, 1024
# current_step = 411, 1024
# current_step = 412, 1024
# current_step = 413, 1024
# current_step = 414, 1024
# current_step = 415, 1024
# current_step = 416, 1024
# current_step = 417, 1024
# current_step = 418, 1024
# current_step = 419, 1024
# current_step = 420, 1024
# current_step = 421, 1024
# current_step = 422, 1024
# current_step = 423, 1024
# current_step = 424, 1024
# current_step = 425, 1024
# current_step = 426, 1024
# current_step = 427, 1024
# current_step = 428, 1024
# current_step = 429, 1024
# current_step = 430, 1024
# current_step = 431, 1024
# current_step = 432, 1024
# current_step = 433, 1024
# current_step = 434, 1024
# current_step = 435, 1024
# current_step = 436, 1024
# current_step = 437, 1024
# current_step = 438, 1024
# current_step = 439, 1024
# current_step = 440, 1024
# current_step = 441, 1024
# current_step = 442, 1024
# current_step = 443, 1024
# current_step = 444, 1024
# current_step = 445, 1024
# current_step = 446, 1024
# current_step = 447, 1024
# current_step = 448, 1024
# current_step = 449, 1024
# current_step = 450, 1024
# current_step = 451, 1024
# current_step = 452, 1024
# current_step = 453, 1024
# current_step = 454, 1024
# current_step = 455, 1024
# current_step = 456, 1024
# current_step = 457, 1024
# current_step = 458, 1024
# current_step = 459, 1024
# current_step = 460, 1024
# current_step = 461, 1024
# current_step = 462, 1024
# current_step = 463, 1024
# current_step = 464, 1024
# current_step = 465, 1024
# current_step = 466, 1024
# current_step = 467, 1024
# current_step = 468, 1024
# current_step = 469, 1024
# current_step = 470, 1024
# current_step = 471, 1024
# current_step = 472, 1024
# current_step = 473, 1024
# current_step = 474, 1024
# current_step = 475, 1024
# current_step = 476, 1024
# current_step = 477, 1024
# current_step = 478, 1024
# current_step = 479, 1024
# current_step = 480, 1024
# current_step = 481, 1024
# current_step = 482, 1024
# current_step = 483, 1024
# current_step = 484, 1024
# current_step = 485, 1024
# current_step = 486, 1024
# current_step = 487, 1024
# current_step = 488, 1024
# current_step = 489, 1024
# current_step = 490, 1024
# current_step = 491, 1024
# current_step = 492, 1024
# current_step = 493, 1024
# current_step = 494, 1024
# current_step = 495, 1024
# current_step = 496, 1024
# current_step = 497, 1024
# current_step = 498, 1024
# current_step = 499, 1024
# current_step = 500, 1024
# current_step = 501, 1024
# current_step = 502, 1024
# current_step = 503, 1024
# current_step = 504, 1024
# current_step = 505, 1024
# current_step = 506, 1024
# current_step = 507, 1024
# current_step = 508, 1024
# current_step = 509, 1024
# current_step = 510, 1024
# current_step = 511, 1024
# current_step = 512, 1024
# current_step = 513, 1024
# current_step = 514, 1024
# current_step = 515, 1024
# current_step = 516, 1024
# current_step = 517, 1024
# current_step = 518, 1024
# current_step = 519, 1024
# current_step = 520, 1024
# current_step = 521, 1024
# current_step = 522, 1024
# current_step = 523, 1024
# current_step = 524, 1024
# current_step = 525, 1024
# current_step = 526, 1024
# current_step = 527, 1024
# current_step = 528, 1024
# current_step = 529, 1024
# current_step = 530, 1024
# current_step = 531, 1024
# current_step = 532, 1024
# current_step = 533, 1024
# current_step = 534, 1024
# current_step = 535, 1024
# current_step = 536, 1024
# current_step = 537, 1024
# current_step = 538, 1024
# current_step = 539, 1024
# current_step = 540, 1024
# current_step = 541, 1024
# current_step = 542, 1024
# current_step = 543, 1024
# current_step = 544, 1024
# current_step = 545, 1024
# current_step = 546, 1024
# current_step = 547, 1024
# current_step = 548, 1024
# current_step = 549, 1024
# current_step = 550, 1024
# current_step = 551, 1024
# current_step = 552, 1024
# current_step = 553, 1024
# current_step = 554, 1024
# current_step = 555, 1024
# current_step = 556, 1024
# current_step = 557, 1024
# current_step = 558, 1024
# current_step = 559, 1024
# current_step = 560, 1024
# current_step = 561, 1024
# current_step = 562, 1024
# current_step = 563, 1024
# current_step = 564, 1024
# current_step = 565, 1024
# current_step = 566, 1024
# current_step = 567, 1024
# current_step = 568, 1024
# current_step = 569, 1024
# current_step = 570, 1024
# current_step = 571, 1024
# current_step = 572, 1024
# current_step = 573, 1024
# current_step = 574, 1024
# current_step = 575, 1024
# current_step = 576, 1024
# current_step = 577, 1024
# current_step = 578, 1024
# current_step = 579, 1024
# current_step = 580, 1024
# current_step = 581, 1024
# current_step = 582, 1024
# current_step = 583, 1024
# current_step = 584, 1024
# current_step = 585, 1024
# current_step = 586, 1024
# current_step = 587, 1024
# current_step = 588, 1024
# current_step = 589, 1024
# current_step = 590, 1024
# current_step = 591, 1024
# current_step = 592, 1024
# current_step = 593, 1024
# current_step = 594, 1024
# current_step = 595, 1024
# current_step = 596, 1024
# current_step = 597, 1024
# current_step = 598, 1024
# current_step = 599, 1024
# current_step = 600, 1024
# current_step = 601, 1024
# current_step = 602, 1024
# current_step = 603, 1024
# current_step = 604, 1024
# current_step = 605, 1024
# current_step = 606, 1024
# current_step = 607, 1024
# current_step = 608, 1024
# current_step = 609, 1024
# current_step = 610, 1024
# current_step = 611, 1024
# current_step = 612, 1024
# current_step = 613, 1024
# current_step = 614, 1024
# current_step = 615, 1024
# current_step = 616, 1024
# current_step = 617, 1024
# current_step = 618, 1024
# current_step = 619, 1024
# current_step = 620, 1024
# current_step = 621, 1024
# current_step = 622, 1024
# current_step = 623, 1024
# current_step = 624, 1024
# current_step = 625, 1024
# current_step = 626, 1024
# current_step = 627, 1024
# current_step = 628, 1024
# current_step = 629, 1024
# current_step = 630, 1024
# current_step = 631, 1024
# current_step = 632, 1024
# current_step = 633, 1024
# current_step = 634, 1024
# current_step = 635, 1024
# current_step = 636, 1024
# current_step = 637, 1024
# current_step = 638, 1024
# current_step = 639, 1024
# current_step = 640, 1024
# current_step = 641, 1024
# current_step = 642, 1024
# current_step = 643, 1024
# current_step = 644, 1024
# current_step = 645, 1024
# current_step = 646, 1024
# current_step = 647, 1024
# current_step = 648, 1024
# current_step = 649, 1024
# current_step = 650, 1024
# current_step = 651, 1024
# current_step = 652, 1024
# current_step = 653, 1024
# current_step = 654, 1024
# current_step = 655, 1024
# current_step = 656, 1024
# current_step = 657, 1024
# current_step = 658, 1024
# current_step = 659, 1024
# current_step = 660, 1024
# current_step = 661, 1024
# current_step = 662, 1024
# current_step = 663, 1024
# current_step = 664, 1024
# current_step = 665, 1024
# current_step = 666, 1024
# current_step = 667, 1024
# current_step = 668, 1024
# current_step = 669, 1024
# current_step = 670, 1024
# current_step = 671, 1024
# current_step = 672, 1024
# current_step = 673, 1024
# current_step = 674, 1024
# current_step = 675, 1024
# current_step = 676, 1024
# current_step = 677, 1024
# current_step = 678, 1024
# current_step = 679, 1024
# current_step = 680, 1024
# current_step = 681, 1024
# current_step = 682, 1024
# current_step = 683, 1024
# current_step = 684, 1024
# current_step = 685, 1024
# current_step = 686, 1024
# current_step = 687, 1024
# current_step = 688, 1024
# current_step = 689, 1024
# current_step = 690, 1024
# current_step = 691, 1024
# current_step = 692, 1024
# current_step = 693, 1024
# current_step = 694, 1024
# current_step = 695, 1024
# current_step = 696, 1024
# current_step = 697, 1024
# current_step = 698, 1024
# current_step = 699, 1024
# current_step = 700, 1024
# current_step = 701, 1024
# current_step = 702, 1024
# current_step = 703, 1024
# current_step = 704, 1024
# current_step = 705, 1024
# current_step = 706, 1024
# current_step = 707, 1024
# current_step = 708, 1024
# current_step = 709, 1024
# current_step = 710, 1024
# current_step = 711, 1024
# current_step = 712, 1024
# current_step = 713, 1024
# current_step = 714, 1024
# current_step = 715, 1024
# current_step = 716, 1024
# current_step = 717, 1024
# current_step = 718, 1024
# current_step = 719, 1024
# current_step = 720, 1024
# current_step = 721, 1024
# current_step = 722, 1024
# current_step = 723, 1024
# current_step = 724, 1024
# current_step = 725, 1024
# current_step = 726, 1024
# current_step = 727, 1024
# current_step = 728, 1024
# current_step = 729, 1024
# current_step = 730, 1024
# current_step = 731, 1024
# current_step = 732, 1024
# current_step = 733, 1024
# current_step = 734, 1024
# current_step = 735, 1024
# current_step = 736, 1024
# current_step = 737, 1024
# current_step = 738, 1024
# current_step = 739, 1024
# current_step = 740, 1024
# current_step = 741, 1024
# current_step = 742, 1024
# current_step = 743, 1024
# current_step = 744, 1024
# current_step = 745, 1024
# current_step = 746, 1024
# current_step = 747, 1024
# current_step = 748, 1024
# current_step = 749, 1024
# current_step = 750, 1024
# current_step = 751, 1024
# current_step = 752, 1024
# current_step = 753, 1024
# current_step = 754, 1024
# current_step = 755, 1024
# current_step = 756, 1024
# current_step = 757, 1024
# current_step = 758, 1024
# current_step = 759, 1024
# current_step = 760, 1024
# current_step = 761, 1024
# current_step = 762, 1024
# current_step = 763, 1024
# current_step = 764, 1024
# current_step = 765, 1024
# current_step = 766, 1024
# current_step = 767, 1024
# current_step = 768, 1024
# current_step = 769, 1024
# current_step = 770, 1024
# current_step = 771, 1024
# current_step = 772, 1024
# current_step = 773, 1024
# current_step = 774, 1024
# current_step = 775, 1024
# current_step = 776, 1024
# current_step = 777, 1024
# current_step = 778, 1024
# current_step = 779, 1024
# current_step = 780, 1024
# current_step = 781, 1024
# current_step = 782, 1024
# current_step = 783, 1024
# current_step = 784, 1024
# current_step = 785, 1024
# current_step = 786, 1024
# current_step = 787, 1024
# current_step = 788, 1024
# current_step = 789, 1024
# current_step = 790, 1024
# current_step = 791, 1024
# current_step = 792, 1024
# current_step = 793, 1024
# current_step = 794, 1024
# current_step = 795, 1024
# current_step = 796, 1024
# current_step = 797, 1024
# current_step = 798, 1024
# current_step = 799, 1024
# current_step = 800, 1024
# current_step = 801, 1024
# current_step = 802, 1024
# current_step = 803, 1024
# current_step = 804, 1024
# current_step = 805, 1024
# current_step = 806, 1024
# current_step = 807, 1024
# current_step = 808, 1024
# current_step = 809, 1024
# current_step = 810, 1024
# current_step = 811, 1024
# current_step = 812, 1024
# current_step = 813, 1024
# current_step = 814, 1024
# current_step = 815, 1024
# current_step = 816, 1024
# current_step = 817, 1024
# current_step = 818, 1024
# current_step = 819, 1024
# current_step = 820, 1024
# current_step = 821, 1024
# current_step = 822, 1024
# current_step = 823, 1024
# current_step = 824, 1024
# current_step = 825, 1024
# current_step = 826, 1024
# current_step = 827, 1024
# current_step = 828, 1024
# current_step = 829, 1024
# current_step = 830, 1024
# current_step = 831, 1024
# current_step = 832, 1024
# current_step = 833, 1024
# current_step = 834, 1024
# current_step = 835, 1024
# current_step = 836, 1024
# current_step = 837, 1024
# current_step = 838, 1024
# current_step = 839, 1024
# current_step = 840, 1024
# current_step = 841, 1024
# current_step = 842, 1024
# current_step = 843, 1024
# current_step = 844, 1024
# current_step = 845, 1024
# current_step = 846, 1024
# current_step = 847, 1024
# current_step = 848, 1024
# current_step = 849, 1024
# current_step = 850, 1024
# current_step = 851, 1024
# current_step = 852, 1024
# current_step = 853, 1024
# current_step = 854, 1024
# current_step = 855, 1024
# current_step = 856, 1024
# current_step = 857, 1024
# current_step = 858, 1024
# current_step = 859, 1024
# current_step = 860, 1024
# current_step = 861, 1024
# current_step = 862, 1024
# current_step = 863, 1024
# current_step = 864, 1024
# current_step = 865, 1024
# current_step = 866, 1024
# current_step = 867, 1024
# current_step = 868, 1024
# current_step = 869, 1024
# current_step = 870, 1024
# current_step = 871, 1024
# current_step = 872, 1024
# current_step = 873, 1024
# current_step = 874, 1024
# current_step = 875, 1024
# current_step = 876, 1024
# current_step = 877, 1024
# current_step = 878, 1024
# current_step = 879, 1024
# current_step = 880, 1024
# current_step = 881, 1024
# current_step = 882, 1024
# current_step = 883, 1024
# current_step = 884, 1024
# current_step = 885, 1024
# current_step = 886, 1024
# current_step = 887, 1024
# current_step = 888, 1024
# current_step = 889, 1024
# current_step = 890, 1024
# current_step = 891, 1024
# current_step = 892, 1024
# current_step = 893, 1024
# current_step = 894, 1024
# current_step = 895, 1024
# current_step = 896, 1024
# current_step = 897, 1024
# current_step = 898, 1024
# current_step = 899, 1024
# current_step = 900, 1024
# current_step = 901, 1024
# current_step = 902, 1024
# current_step = 903, 1024
# current_step = 904, 1024
# current_step = 905, 1024
# current_step = 906, 1024
# current_step = 907, 1024
# current_step = 908, 1024
# current_step = 909, 1024
# current_step = 910, 1024
# current_step = 911, 1024
# current_step = 912, 1024
# current_step = 913, 1024
# current_step = 914, 1024
# current_step = 915, 1024
# current_step = 916, 1024
# current_step = 917, 1024
# current_step = 918, 1024
# current_step = 919, 1024
# current_step = 920, 1024
# current_step = 921, 1024
# current_step = 922, 1024
# current_step = 923, 1024
# current_step = 924, 1024
# current_step = 925, 1024
# current_step = 926, 1024
# current_step = 927, 1024
# current_step = 928, 1024
# current_step = 929, 1024
# current_step = 930, 1024
# current_step = 931, 1024
# current_step = 932, 1024
# current_step = 933, 1024
# current_step = 934, 1024
# current_step = 935, 1024
# current_step = 936, 1024
# current_step = 937, 1024
# current_step = 938, 1024
# current_step = 939, 1024
# current_step = 940, 1024
# current_step = 941, 1024
# current_step = 942, 1024
# current_step = 943, 1024
# current_step = 944, 1024
# current_step = 945, 1024
# current_step = 946, 1024
# current_step = 947, 1024
# current_step = 948, 1024
# current_step = 949, 1024
# current_step = 950, 1024
# current_step = 951, 1024
# current_step = 952, 1024
# current_step = 953, 1024
# current_step = 954, 1024
# current_step = 955, 1024
# current_step = 956, 1024
# current_step = 957, 1024
# current_step = 958, 1024
# current_step = 959, 1024
# current_step = 960, 1024
# current_step = 961, 1024
# current_step = 962, 1024
# current_step = 963, 1024
# current_step = 964, 1024
# current_step = 965, 1024
# current_step = 966, 1024
# current_step = 967, 1024
# current_step = 968, 1024
# current_step = 969, 1024
# current_step = 970, 1024
# current_step = 971, 1024
# current_step = 972, 1024
# current_step = 973, 1024
# current_step = 974, 1024
# current_step = 975, 1024
# current_step = 976, 1024
# current_step = 977, 1024
# current_step = 978, 1024
# current_step = 979, 1024
# current_step = 980, 1024
# current_step = 981, 1024
# current_step = 982, 1024
# current_step = 983, 1024
# current_step = 984, 1024
# current_step = 985, 1024
# current_step = 986, 1024
# current_step = 987, 1024
# current_step = 988, 1024
# current_step = 989, 1024
# current_step = 990, 1024
# current_step = 991, 1024
# current_step = 992, 1024
# current_step = 993, 1024
# current_step = 994, 1024
# current_step = 995, 1024
# current_step = 996, 1024
# current_step = 997, 1024
# current_step = 998, 1024
# current_step = 999, 1024
# current_step = 1000, 1024
# current_step = 1001, 1024
# current_step = 1002, 1024
# current_step = 1003, 1024
# current_step = 1004, 1024
# current_step = 1005, 1024
# current_step = 1006, 1024
# current_step = 1007, 1024
# current_step = 1008, 1024
# current_step = 1009, 1024
# current_step = 1010, 1024
# current_step = 1011, 1024
# current_step = 1012, 1024
# current_step = 1013, 1024
# current_step = 1014, 1024
# current_step = 1015, 1024
# current_step = 1016, 1024
# current_step = 1017, 1024
# current_step = 1018, 1024
# current_step = 1019, 1024
# current_step = 1020, 1024
# current_step = 1021, 1024
# current_step = 1022, 1024
# current_step = 1023, 1024
# current_step = 1024, 1024
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 70
#      66 # checkpoint_callback = CheckpointCallback(save_freq=5000, save_path='./logs/', name_prefix='dryer_model')
#      67 # trained_model = train_dryer_model(model_path_name=model_path_name, total_timesteps=10000, n_epochs=1)
#      68 print(f"Trained will start. [{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}]")
#      69
# ---> 70 trained_model, trained_model_path_name = train_dryer_model_from_csv(model_path_name=model_path_name,
#      71                                                                     n_steps=n_steps,
#      72                                                                     csv_path=stored_data_file_pathname,
#      73                                                                     reward_gen_fn_pathname=reward_gen_fn_pythonfile,
#
# Cell In[21], line 50, in train_dryer_model_from_csv(model_path_name, n_steps, csv_path, reward_gen_fn_pathname, n_epochs, learn_repeat_cnt, callback)
#      46     if callback is not None:
#      47         model.learn(total_timesteps=len(base_env.df) * learn_repeat_cnt,  # 데이터를 5번 반복 학습
#      48                     callback=callback)
#      49     else:
# ---> 50         model.learn(total_timesteps=len(base_env.df) * learn_repeat_cnt)  # 데이터를 5번 반복 학습
#      51
#      52     trained_model_path_name = model_path_name()
#      53     # 4. 저장
#
# File ~/work/mlops_jupyter_notebooks_simpson/env/samplemodelingv4_3/lib/python3.12/site-packages/sb3_contrib/ppo_recurrent/ppo_recurrent.py:450, in RecurrentPPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     441 def learn(
#     442     self: SelfRecurrentPPO,
#     443     total_timesteps: int,
#    (...)    448     progress_bar: bool = False,
#     449 ) -> SelfRecurrentPPO:
# --> 450     return super().learn(
#     451         total_timesteps=total_timesteps,
#     452         callback=callback,
#     453         log_interval=log_interval,
#     454         tb_log_name=tb_log_name,
#     455         reset_num_timesteps=reset_num_timesteps,
#     456         progress_bar=progress_bar,
#     457     )
#
# File ~/work/mlops_jupyter_notebooks_simpson/env/samplemodelingv4_3/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:324, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     321 assert self.env is not None
#     323 while self.num_timesteps < total_timesteps:
# --> 324     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     326     if not continue_training:
#     327         break
#
# File ~/work/mlops_jupyter_notebooks_simpson/env/samplemodelingv4_3/lib/python3.12/site-packages/sb3_contrib/ppo_recurrent/ppo_recurrent.py:252, in RecurrentPPO.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     249 if isinstance(self.action_space, spaces.Box):
#     250     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 252 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     254 self.num_timesteps += env.num_envs
#     256 # Give access to local variables
#
# File ~/work/mlops_jupyter_notebooks_simpson/env/samplemodelingv4_3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~/work/mlops_jupyter_notebooks_simpson/env/samplemodelingv4_3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# Cell In[19], line 204, in DryerEnv.step(self, action)
#     200         if self.current_step > self.max_steps:
#     201             self.current_step = self.max_steps # 인덱스 초과 방지
#     202
#     203         # print(f'self.state #0 = {self.state}')
# --> 204         self.state = self._load_observation(action=action,current_step=self.current_step)
#     205
#     206         for i in range(len(self.state)):
#     207             self.state[i] = DryerEnv._unpack_nptype(self.state[i])
#
# Cell In[20], line 18, in CSVDataDryerEnv._load_observation(self, action, current_step)
#      15     def _load_observation(self, action: int = 1, current_step: int = 0):
#      16         # CSV의 특정 행에서 데이터를 가져와서 state로 반환
#      17         print(f'current_step = {current_step}, {len(self.df)}')
# ---> 18         row = self.df.iloc[current_step]
#      19         return np.array([
#      20             row['timestamp'],
#      21             row['inner_temp'],
#
# File ~/work/mlops_jupyter_notebooks_simpson/env/samplemodelingv4_3/lib/python3.12/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/work/mlops_jupyter_notebooks_simpson/env/samplemodelingv4_3/lib/python3.12/site-packages/pandas/core/indexing.py:1773, in _iLocIndexer._getitem_axis(self, key, axis)
#    1770     raise TypeError("Cannot index by location index with a non-integer key")
#    1772 # validate the location
# -> 1773 self._validate_integer(key, axis)
#    1775 return self.obj._ixs(key, axis=axis)
#
# File ~/work/mlops_jupyter_notebooks_simpson/env/samplemodelingv4_3/lib/python3.12/site-packages/pandas/core/indexing.py:1706, in _iLocIndexer._validate_integer(self, key, axis)
#    1704 len_axis = len(self.obj._get_axis(axis))
#    1705 if key >= len_axis or key < -len_axis:
# -> 1706     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ##### 4. Test

# %%
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
# from lib.callback.ppo_event_callback import PPOEventCallback
from stable_baselines3.common.vec_env import DummyVecEnv

inner_temp_history = []
action_history = []
reward_history = []
repeat_cnt = 200
learn_timesteps = -1
# trained_model_path_name ="./model/ppo_dryer_control_v1.1_20260329_231930.pth"  # 방금 저장한 모델 경로 사용

def test_model(model_path_name,
               repeat_cnt=100,
               reward_gen_fn_pathname=None,
               learn_timesteps=1,
               is_simulatation=True,
               simulation_cls_pahname=None):
    # 저장된 모델 로드 및 테스트

    # 1. 원본 환경 생성
    base_env = DryerEnv(reward_gen_fn_pathname=reward_gen_fn_pathname,
                        is_simulatation=is_simulatation,
                        simulation_cls_pahname=simulation_cls_pahname
                        )
    env = DummyVecEnv([lambda: base_env])
    model = RecurrentPPO.load(model_path_name)
    # 2. Monitor 래핑 (표준 규격 및 로그 기록)
    model.env = env
    obs = model.env.reset()

    if isinstance(model.action_space, gym.spaces.Discrete):
        print("이 모델은 [이산(Discrete)] 환경용입니다. (Logits 사용 가능)")
    elif isinstance(model.action_space, gym.spaces.Box):
        print("이 모델은 [연속(Continuous)] 환경용입니다. (Logits 없음, MSE 사용 필요)")
    print(f'테스트를 시작합니다. [{datetime.now()}]')

    in_obs = obs
    # print(f"in_obs = {in_obs}")

    inner_temp_history.append(in_obs[0][1])

    # LSTM 상태 초기화 (Recurrent 모델은 상태 관리가 필요함)
    lstm_states = None
    episode_starts = np.ones((1,), dtype=bool)
    for i in range(repeat_cnt):
        # 모델 예측 (deterministic=True: 가장 확률 높은 액션 선택)
        action, _ = model.predict(
            in_obs,
            state=lstm_states,
            episode_start=episode_starts.
            deterministic=True
        )
        step_results = model.env.step(action)
        # print(f'step_results = {step_results}, {type(step_results)}')
        predict_obs = step_results[0][0].tolist()
        diff = predict_obs[1] - in_obs[0][1]
        if abs(diff) < 0.001:
            print(f"Step {i}: In ={in_obs}[{type(in_obs)}], Action={action}")            
            print(f"Step {i}: Out ={predict_obs}, Action={action}, Reward={reward:.2f}")
            print(f'not changed, diff = {diff}')
        in_obs = [predict_obs]
        reward = step_results[1][0]
        if i > 0 and learn_timesteps > 0 and i % learn_timesteps == 0:
            print(f"Step {i}: Learning from experience...")
            model.learn(total_timesteps=learn_timesteps, reset_num_timesteps=False, log_interval=None)

        inner_temp_history.append(predict_obs[1])
        action_history.append(int(action.item()))
        reward_history.append(reward)
        # if terminated or truncated:
        #     break


print(f"Testing model {trained_model_path_name} for {repeat_cnt} steps...")

test_model(model_path_name=trained_model_path_name,
           repeat_cnt=repeat_cnt,
           reward_gen_fn_pathname=reward_gen_fn_pythonfile,
           learn_timesteps=learn_timesteps,
           is_simulatation=True,
           simulation_cls_pahname=simulation_cls_pathname)

plt.plot(inner_temp_history, label='Inner Temperature')
plt.axhline(15, color='r', linestyle='--', label='Target')
plt.title("Inner Temperature")
plt.legend()
plt.show()
# Out:
# Testing model ./model/ppo_dryer_control_v1.1_20260330_172354.pth for 200 steps...
# module_path_name = /home/jupyter-spire_modeler/work/mlops_jupyter_notebooks/lib/simulate/dryer_oven_simulation.py
# ModuleSpec(name='classname', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7731b01a0c80>, origin='/home/jupyter-spire_modeler/work/mlops_jupyter_notebooks/lib/simulate/dryer_oven_simulation.py') <class '_frozen_importlib.ModuleSpec'>
# Step 30: In =[[0.0, 53.43662643432617, -26.563373565673828, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 30: Out =[0.0, 53.43743133544922, -26.56256866455078, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.61
# not changed, diff = 0.000804901123046875
# Step 31: In =[[0.0, 53.43743133544922, -26.56256866455078, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 31: Out =[0.0, 53.43803405761719, -26.561965942382812, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.57
# not changed, diff = 0.00060272216796875
# Step 32: In =[[0.0, 53.43803405761719, -26.561965942382812, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 32: Out =[0.0, 53.438480377197266, -26.561519622802734, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.54
# not changed, diff = 0.000446319580078125
# Step 33: In =[[0.0, 53.438480377197266, -26.561519622802734, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 33: Out =[0.0, 53.438812255859375, -26.561187744140625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.51
# not changed, diff = 0.000331878662109375
# Step 34: In =[[0.0, 53.438812255859375, -26.561187744140625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 34: Out =[0.0, 53.43906021118164, -26.56093978881836, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.50
# not changed, diff = 0.000247955322265625
# Step 35: In =[[0.0, 53.43906021118164, -26.56093978881836, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 35: Out =[0.0, 53.439247131347656, -26.560752868652344, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.48
# not changed, diff = 0.000186920166015625
# Step 36: In =[[0.0, 53.439247131347656, -26.560752868652344, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 36: Out =[0.0, 53.43938446044922, -26.56061553955078, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.47
# not changed, diff = 0.0001373291015625
# Step 37: In =[[0.0, 53.43938446044922, -26.56061553955078, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 37: Out =[0.0, 53.43948745727539, -26.56051254272461, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.47
# not changed, diff = 0.000102996826171875
# Step 38: In =[[0.0, 53.43948745727539, -26.56051254272461, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 38: Out =[0.0, 53.4395637512207, -26.560436248779297, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.46
# not changed, diff = 7.62939453125e-05
# Step 39: In =[[0.0, 53.4395637512207, -26.560436248779297, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 39: Out =[0.0, 53.43962097167969, -26.560379028320312, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.46
# not changed, diff = 5.7220458984375e-05
# Step 40: In =[[0.0, 53.43962097167969, -26.560379028320312, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 40: Out =[0.0, 53.43966293334961, -26.56033706665039, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 4.1961669921875e-05
# Step 41: In =[[0.0, 53.43966293334961, -26.56033706665039, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 41: Out =[0.0, 53.439697265625, -26.560302734375, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 3.4332275390625e-05
# Step 42: In =[[0.0, 53.439697265625, -26.560302734375, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 42: Out =[0.0, 53.439720153808594, -26.560279846191406, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 2.288818359375e-05
# Step 43: In =[[0.0, 53.439720153808594, -26.560279846191406, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 43: Out =[0.0, 53.43973922729492, -26.560260772705078, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 1.9073486328125e-05
# Step 44: In =[[0.0, 53.43973922729492, -26.560260772705078, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 44: Out =[0.0, 53.43975067138672, -26.56024932861328, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 1.1444091796875e-05
# Step 45: In =[[0.0, 53.43975067138672, -26.56024932861328, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 45: Out =[0.0, 53.439762115478516, -26.560237884521484, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 1.1444091796875e-05
# Step 46: In =[[0.0, 53.439762115478516, -26.560237884521484, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 46: Out =[0.0, 53.43976974487305, -26.560230255126953, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 7.62939453125e-06
# Step 47: In =[[0.0, 53.43976974487305, -26.560230255126953, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 47: Out =[0.0, 53.43977355957031, -26.560226440429688, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 3.814697265625e-06
# Step 48: In =[[0.0, 53.43977355957031, -26.560226440429688, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 48: Out =[0.0, 53.43977737426758, -26.560222625732422, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 3.814697265625e-06
# Step 49: In =[[0.0, 53.43977737426758, -26.560222625732422, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 49: Out =[0.0, 53.439781188964844, -26.560218811035156, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 3.814697265625e-06
# Step 50: In =[[0.0, 53.439781188964844, -26.560218811035156, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 50: Out =[0.0, 53.43978500366211, -26.56021499633789, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 3.814697265625e-06
# Step 51: In =[[0.0, 53.43978500366211, -26.56021499633789, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 51: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.45
# not changed, diff = 3.814697265625e-06
# Step 52: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 52: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 53: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 53: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 54: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 54: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 55: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 55: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 56: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 56: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 57: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 57: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 58: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 58: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 59: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 59: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 60: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 60: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 61: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 61: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 62: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 62: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 63: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 63: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 64: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 64: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 65: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 65: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 66: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 66: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 67: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 67: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 68: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 68: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 69: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 69: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 70: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 70: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 71: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 71: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 72: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 72: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 73: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 73: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 74: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 74: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 75: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 75: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 76: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 76: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 77: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 77: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 78: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 78: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 79: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 79: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 80: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 80: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 81: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 81: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 82: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 82: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 83: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 83: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 84: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 84: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 85: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 85: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 86: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 86: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 87: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 87: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 88: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 88: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 89: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 89: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 90: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 90: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 91: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 91: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 92: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 92: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 93: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 93: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 94: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 94: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 95: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 95: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 96: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 96: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 97: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 97: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 98: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 98: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 99: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 99: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 100: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 100: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 101: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 101: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 102: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 102: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 103: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 103: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 104: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 104: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 105: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 105: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 106: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 106: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 107: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 107: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 108: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 108: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 109: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 109: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 110: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 110: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 111: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 111: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 112: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 112: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 113: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 113: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 114: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 114: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 115: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 115: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 116: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 116: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 117: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 117: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 118: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 118: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 119: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 119: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 120: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 120: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 121: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 121: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 122: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 122: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 123: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 123: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 124: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 124: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 125: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 125: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 126: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 126: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 127: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 127: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 128: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 128: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 129: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 129: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 130: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 130: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 131: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 131: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 132: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 132: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 133: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 133: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 134: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 134: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 135: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 135: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 136: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 136: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 137: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 137: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 138: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 138: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 139: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 139: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 140: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 140: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 141: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 141: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 142: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 142: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 143: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 143: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 144: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 144: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 145: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 145: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 146: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 146: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 147: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 147: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 148: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 148: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 149: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 149: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 150: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 150: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 151: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 151: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 152: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 152: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 153: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 153: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 154: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 154: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 155: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 155: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 156: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 156: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 157: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 157: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 158: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 158: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 159: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 159: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 160: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 160: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 161: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 161: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 162: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 162: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 163: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 163: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 164: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 164: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 165: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 165: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 166: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 166: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 167: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 167: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 168: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 168: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 169: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 169: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 170: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 170: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 171: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 171: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 172: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 172: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 173: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 173: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 174: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 174: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 175: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 175: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 176: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 176: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 177: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 177: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 178: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 178: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 179: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 179: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 180: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 180: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 181: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 181: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 182: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 182: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 183: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 183: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 184: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 184: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 185: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 185: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 186: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 186: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 187: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 187: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 188: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 188: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 189: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 189: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 190: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 190: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 191: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 191: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 192: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 192: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 193: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 193: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 194: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 194: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 195: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 195: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 196: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 196: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 197: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 197: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 198: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 198: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
# Step 199: In =[[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0]][<class 'list'>], Action=[1]
# Step 199: Out =[0.0, 53.439788818359375, -26.560211181640625, 0.0, 20.0, 22.0, 1013.0, 1900.0], Action=[1], Reward=-755.44
# not changed, diff = 0.0
